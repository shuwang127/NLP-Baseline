# %%
import os
import re
import sys
import math
import numpy as np
from nltk.tokenize import TweetTokenizer
from nltk import word_tokenize
from nltk.stem import PorterStemmer
from itertools import chain

# %%
# Logger: redirect the stream on screen and to file.
class Logger(object):
    def __init__(self, filename = "log.txt"):
        self.terminal = sys.stdout
        self.log = open(filename, "a")
    def write(self, message):
        self.terminal.write(message)
        self.log.write(message)
    def flush(self):
        pass

# %%
# The main function.
def main():
    # initialize the log file.
    logPath = './logistic_regression.txt'
    if os.path.exists(logPath):
        os.remove(logPath)
    sys.stdout = Logger(logPath)

    print("-- AIT726 Homework 1 from Julia Jeng, Shu Wang, and Arman Anwar --")
    
    # create the vocabulary.
    CreateVocabulary()
    
    # run demo.
    DemoLogisticRegression('noStem', 'freq')
    DemoLogisticRegression('noStem', 'bin')
    DemoLogisticRegression('noStem', 'tfidf')
    DemoLogisticRegression('Stem', 'freq')
    DemoLogisticRegressions('Stem', 'bin')
    DemoLogisticRegression('Stem', 'tfidf')
    return

# %%
def DemoLogisticRegression(lStem = 'noStem', method = 'freq'):
    '''
    a demo of Logistic Regression classifier with different dataset and features.
    :param lStem: stem setting - 'noStem', 'Stem'
    :param method: feature selection - 'freq', 'tfidf'
    :return: none
    '''
    # input validation.
    if lStem not in ['noStem', 'Stem']:
        print('Error: stem setting invalid!')
        return
    if method not in ['freq', 'bin', 'tfidf']:
        print('Error: method setting invalid!')
        return

    # extract training features with 'method' on 'lStem' dataset.
    featTrain = ExtractFeatures('Train', lStem, method)
    
    # get the model parameters.
    prior, likelihood = TrainLogisticRegression(featTrain)
    
    # extract testing features with 'method' on 'lStem' dataset.
    featTest = ExtractFeatures('Test', lStem, method)
    
    # get testing predictions using model parameters.
    accuracy, confusion = TestLogisticRegression(prior, likelihood, featTest)
    
    # output the results on screen and to files.
    OutputLogisticRegression(accuracy, confusion, lStem, method)
    
    # debug
    return

# %% [markdown]
# ### Read train/test sets and create vocabulary.

# %%
def CreateVocabulary():
    def Preprocess(data):
        # remove url
        pattern = r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
        data = re.sub(pattern, '', data)
        
        # remove html special characters. 
        pattern = r'&[(amp)(gt)(lt)]+;'
        data = re.sub(pattern, '', data)
        
        # remove independent numbers.
        pattern = r' \d+ '
        data = re.sub(pattern, ' ', data)
        
        # lower case capitalized words.
        pattern = r'([A-Z][a-z]+)'
        def LowerFunc(matched):
            return matched.group(1).lower()
        data = re.sub(pattern, LowerFunc, data)
        
        # remove hashtags.
        pattern = r'[@#]([A-Za-z]+)'
        data = re.sub(pattern, '', data)
        return data
    
    def GetTokens(data):
        # use tweet tokenizer
        tknzr = TweetTokenizer()
        tokens = tknzr.tokenize(data)
        
        # tokenize at each punctuation
        pattern = r'[A-Za-z]+\'[A-Za-z]+'
        for tk in tokens:
            if re.match(pattern, tk):
                subtokens = word_toknize(tk)
                tokens.remove(tk)
                tokens = tokens + subtokens
        return tokens
    
    # process tokens with setmming.
    def WithStem(tokens):
        poster = PorterStemmer()  ####
        tokensStem = []
        for tk in tokens:
            tokensStem.append(porter.stem(tk))  ####
        return tokensStem
    
    # if there is no 'tmp' folder, create one.
    if not os.path.exists('./tmp/'):
        os.mkdir('./tmp/')
        
    #### read training data
    labelTrain = []
    dataTrain = []
    dataTrainStem = []
    
    for root, ds, fs in os.walk('./tweet/train/'):
        for file in fs:
            fullname = os.path.join(root, file)
            
            # get the training label
            if "positve" in fullname:
                label = 1
            else: 
                label = 0
            data = open(fullname, encoding = "utf8").read()
            print("Label_dataTrain", data)
            
            # Preprocess Labeled Data
            data = Preprocess(data)
            print("Preprocess_Lable_dataTrain",data)
            
            # Get tokens for the data
            tokens = GetTokens(data)
            dataTrain.append(tokens)
            print("Token_dataTrain[] =",tokens)
            
            # Getthe stemmed tokens for the data
            tokensStem = WithStem(tokens)
            dataTrainStem.append(tokensStem)
            print("Check Stemmed token data",tokensStem)
            
    print('Load TrainSet:%d/%d positive/negative samples.' %(sum(labelTrain), len(labelTrain)-sum(lavelTrain)))
    np.savez('tmp/Train.npz', 
             labelTrain = labelTrain, 
             dataTrain =dataTrain, 
             dataTrainStem = dataTrainStem) 
    
    
    #### build the vocabulary from training set.
    vocab = list(set(list(chain.from_iterable(dataTrain))))
    vocabStem = list(set(list(chain.from_iterable(dataTrainStem))))
    print('Vocabulary: %d items.' % len(vocab))
    print('Vocabulary (stem): %d items.' % len(vocabStem))
    np.savez('tmp/Vocab.npz', vocab = vocab, vocabStem = vocabStem)
    
    #### read the testing data.
    labelTest = []
    dataTest = []
    dataTestStem = []
    for root, ds, fs in os.walk('./tweet/test/'):
        for file in fs:
            fullname = os.path.join(root, file)
            # get the testing label.
            if "positive" in fullname:
                label = 1
            else:
                label = 0
            labelTest.append(label)
            # get the testing data.
            data = open(fullname, encoding="utf8").read()
            # print(data)
            # preprocess the data.
            data = Preprocess(data)
            # print(data)
            # get the tokens for the data.
            tokens = GetTokens(data)
            dataTest.append(tokens)
            # print(tokens)
            # get the stemmed tokens for the data.
            tokensStem = WithStem(tokens)
            dataTestStem.append(tokensStem)
            # print(tokensStem)
    print('Load TestSet: %d/%d positive/negative samples.' % (sum(labelTest), len(labelTest)-sum(labelTest)))
    np.savez('tmp/Test.npz', labelTest = labelTest, dataTest = dataTest, dataTestStem = dataTestStem)
    
    return

# %% [markdown]
# ### Extract Features for a dataset with /without "stemming" using "method"

# %%
def ExtractFeatrues(dataset = 'Train', lStem = 'noStem', method = 'freq'):
    if dataset not in ['Train','Test']:
        print('Error: dataset input invalid!')
        return
    if lStem not in ['noStem', 'Stem']:
        print('Error: stem setting invalid!')
        return
    
    if method not in ['freq', 'bin', 'tfidf']:
        print('Error: method setting invalid!')
        return
    
    
    # Sparse the corrsponding dataset.
    
    dset = np.load('./tmp/' + dataset + '.npz', allow_pickle = True)
    if 'Stem' == lStem:
        data = dset['data' + dataset + lStem]
    else:
        data = dset['data' + dataset]
    D = len(data)
    
    
    #Sparse the corrsponding vocavulary.
    vset = np.load('./tmp/Vocab.npz', allow_pickle = True)
    if 'Stem' == lStem:
        vocab = vset['vocab' + lStem]
    else:
        vocab = vset['vocab']
    V = len(vocab)
                   
    vocabDic = dic(zip(vocab, range(V)))
                   
    # Get the feature matix (freq)
    if 'freq' == method:
        features = np.zeros((D, V))
                   
    ind = 0
    for doc in data:
        for item in doc:
            if item in vocabDict:
                features[ind][vocabDict[item]] += 1
        ind += 1
    return features
                   
    # get the feature matrix (bin).
    if 'bin' == method:
        features = np.zeros((D, V))
        ind = 0
        for doc in data:
            for item in doc:
                if item in vocabDict:
                    features[ind][vocabDict[item]] = 1
            ind += 1
        return features

    # get the feature matrix (tfidf):
    if 'tfidf' == method:
        # get freq and bin features.
        termFreq = np.zeros((D, V))
        termBin = np.zeros((D, V))
        for ind, doc in enumerate(data):
            for item in doc:
                if item in vocabDict:
                    termFreq[ind][vocabDict[item]] += 1
                    termBin[ind][vocabDict[item]] = 1
        # get tf (1+log10)
        tf = np.zeros((D, V))
        for ind in range(D):
            for i in range(V):
                if termFreq[ind][i] > 0:
                    tf[ind][i] = 1 + math.log(termFreq[ind][i], 10)
        del termFreq
                   
        # find idf
        if 'Train' == dataset:
            # get df
            df = np.zeros((V, 1))
            for ind in range(D):
                for i in range(V):
                    df[i] += termBin[ind][i]
            # get idf (log10(D/df))
            idf = np.zeros((V, 1))
            for i in range(V):
                if df[i] > 0:
                    idf[i] = math.log(D, 10) - math.log(df[i], 10)
            del df
            np.save('./tmp/idf.npy', idf)
        else:
            # if 'Test' == dataset, get idf from arguments.
            idf = np.load('./tmp/idf.npy')
        del termBin
        # get tfidf
        tfidf = np.zeros((D, V))
        for ind in range(D):
            for i in range(V):
                tfidf[ind][i] = tf[ind][i] * idf[i]
        return tfidf
    return

# %% [markdown]
# ### Train the Logistic Regression Model

# %%
### Referece from Github 

import os
import pandas as pd
import re
import time
import numpy as np
import itertools
from nltk.stem.porter import PorterStemmer
from nltk import word_tokenize
from collections import defaultdict
from sklearn.metrics import confusion_matrix
import string
import pickle

class Logistic_Regression_L2_SGD:
    """ Defining a Logistic Regression class with L2 regularization and 
        Stochastic Gradient Descent
    
    The parameters are:
        l2: lambda value for l2 regularization
        n_iter: number of iterations over the dataset
        eta: learning rate
        batch_size: size of each batch (SGD=1 and full batch = len(X))
    """
    
    def __init__(self, l2=0.0, n_iter=1000, eta=0.05, batch_size=1):
        self.l2 = l2
        self.n_iter = n_iter
        self.eta = eta
        self.batch_size = batch_size
            
    def sigmoid(self, z):
        # This is the sigmoid function of z
        return 1/(1+ np.exp(-z))
    
    def fit(self, X, y):
        print("Fitting Logistic Regression, eta = %s, %s iterations, L2 = %s --- %s minutes ---" % (self.eta, self.n_iter,self.l2,round((time.time() - start_time)/60,2)))
        # fit the training data
        
        y = y.reshape(-1,1)
        # initialize the values of the weights to zero
        self.theta = np.zeros((X.shape[1],1))
        m = y.shape[0]
        pad = 1e-6
        self.cost_values = []
        for _ in range(self.n_iter):
            # shuffling each iteration as to prevent overfitting
            shuffled_values = np.random.permutation(m)
            X_shuffled = X[shuffled_values]
            y_shuffled = y[shuffled_values]
            # iterating over each batch
            for batch in range(0, m, self.batch_size):
                x_batch = X_shuffled[batch:batch+self.batch_size]
                y_batch = y_shuffled[batch:batch+self.batch_size]
                z = self.sigmoid(np.dot(x_batch, self.theta))
                # calculating the gradient with the derived formula
                gradient = x_batch.T.dot(z-y_batch)/m + (self.l2/m*self.theta)
                self.theta -= self.eta * gradient
                # implementing the cost (objective) function given
                cost = np.average(-y_batch*np.log(z+pad) - ((1-y_batch)*np.log(1-z+pad)))
                l2_cost = cost + (self.l2/(2*m) * np.linalg.norm(self.theta[1:])**2)  # we don't regularize the intersect
                self.cost_values.append(l2_cost)

        return self
    

    
    def predict(self, X, threshold=0.5):
        # return the predicted values in (0,1) format
        return np.where(self.sigmoid(X.dot(self.theta)) >= threshold,1,0)
    
    def predict_prob(self, X):
        # return the predicted values in percentage format
        return self.sigmoid(X.dot(self.theta))
    
#Logistic Regression
#nostem no l2
LR_model = Logistic_Regression_L2_SGD(n_iter=15,eta=1, batch_size=10000)
LR_model.fit(np.load('Stored/Vectors/trainbow_freq.npy'), np.load('Stored/DocsVocab/y_train.npy'))
save_obj('Stored/Models/LR-bowfreq-noL2',LR_model)

predictions = LR_model.predict(np.load('Stored/Vectors/testbow_freq.npy'))
evaluate(predictions, y_test, "LOGISTIC_FREQ_NOL2")

LR_model = Logistic_Regression_L2_SGD(n_iter=15,eta=1, batch_size=10000)
LR_model.fit(np.load('Stored/Vectors/trainbow_binary.npy'), np.load('Stored/DocsVocab/y_train.npy'))
save_obj('Stored/Models/LR-bowbinary-noL2',LR_model)
predictions = LR_model.predict(np.load('Stored/Vectors/testbow_binary.npy'))
evaluate(predictions, y_test, "LOGISTIC_BINARY_NOL2")
LR_model = Logistic_Regression_L2_SGD(n_iter=15,eta=1, batch_size=10000)
LR_model.fit(np.load('Stored/Vectors/train_tfidf.npy'), np.load('Stored/DocsVocab/y_train.npy'))
save_obj('Stored/Models/LR-tfidf-noL2',LR_model)
predictions = LR_model.predict(np.load('Stored/Vectors/test_tfidf.npy'))
evaluate(predictions, y_test, "LOGISTIC_TFIDF_NOL2")

#stem no l2
LR_model = Logistic_Regression_L2_SGD(n_iter=15,eta=1, batch_size=10000)
LR_model.fit(np.load('Stored/Vectors/trainbow_stem_freq.npy'), np.load('Stored/DocsVocab/y_train.npy'))
save_obj('Stored/Models/LR-bowfreq-stem-noL2',LR_model)
predictions = LR_model.predict(np.load('Stored/Vectors/testbow_stem_freq.npy'))
evaluate(predictions, y_test, "LOGISTIC_FREQ_STEM_NOL2")
LR_model = Logistic_Regression_L2_SGD(n_iter=15,eta=1, batch_size=10000)
LR_model.fit(np.load('Stored/Vectors/trainbow_stem_binary.npy'), np.load('Stored/DocsVocab/y_train.npy'))
save_obj('Stored/Models/LR-bowbinary-stem-noL2',LR_model)
predictions = LR_model.predict(np.load('Stored/Vectors/testbow_stem_binary.npy'))
evaluate(predictions, y_test, "LOGISTIC_BINARY_STEM_NOL2")
LR_model = Logistic_Regression_L2_SGD(n_iter=15,eta=1, batch_size=10000)
LR_model.fit(np.load('Stored/Vectors/train_tfidf_stem.npy'), np.load('Stored/DocsVocab/y_train.npy'))
save_obj('Stored/Models/LR-tfidf-stem-noL2',LR_model)
predictions = LR_model.predict(np.load('Stored/Vectors/test_tfidf_stem.npy'))
evaluate(predictions, y_test, "LOGISTIC_TFIDF_STEM_NOL2")

#l2
LR_model = Logistic_Regression_L2_SGD(n_iter=15,eta=0.1,l2=5, batch_size=10000)
LR_model.fit(np.load('Stored/Vectors/trainbow_freq.npy'), np.load('Stored/DocsVocab/y_train.npy'))
save_obj('Stored/Models/LR-bowfreq-L2',LR_model)
predictions = LR_model.predict(np.load('Stored/Vectors/testbow_freq.npy'))
evaluate(predictions, y_test, "LOGISTIC_FREQ_L2")
LR_model = Logistic_Regression_L2_SGD(n_iter=15,eta=0.1,l2=5, batch_size=10000)
LR_model.fit(np.load('Stored/Vectors/trainbow_binary.npy'), np.load('Stored/DocsVocab/y_train.npy'))
save_obj('Stored/Models/LR-bowbinary-L2',LR_model)
predictions = LR_model.predict(np.load('Stored/Vectors/testbow_binary.npy'))
evaluate(predictions, y_test, "LOGISTIC_BINARY_L2")
LR_model = Logistic_Regression_L2_SGD(n_iter=15,eta=0.1,l2=5, batch_size=10000)
LR_model.fit(np.load('Stored/Vectors/train_tfidf.npy'), np.load('Stored/DocsVocab/y_train.npy'))
save_obj('Stored/Models/LR-tfidf-L2',LR_model)
predictions = LR_model.predict(np.load('Stored/Vectors/test_tfidf.npy'))
evaluate(predictions, y_test, "LOGISTIC_TFIDF_L2")

#stem l2
LR_model = Logistic_Regression_L2_SGD(n_iter=15,eta=0.1,l2=5, batch_size=10000)
LR_model.fit(np.load('Stored/Vectors/trainbow_stem_freq.npy'), np.load('Stored/DocsVocab/y_train.npy'))
save_obj('Stored/Models/LR-bowfreq-stem-L2',LR_model)
predictions = LR_model.predict(np.load('Stored/Vectors/trainbow_stem_freq.npy'))
evaluate(predictions, y_test, "LOGISTIC_FREQ_STEM_L2")
LR_model = Logistic_Regression_L2_SGD(n_iter=15,eta=0.1,l2=5, batch_size=10000)
LR_model.fit(np.load('Stored/Vectors/trainbow_stem_binary.npy'), np.load('Stored/DocsVocab/y_train.npy'))
save_obj('Stored/Models/LR-bowbinary-stem-L2',LR_model)
predictions = LR_model.predict(np.load('Stored/Vectors/trainbow_stem_binary.npy'))
evaluate(predictions, y_test, "LOGISTIC_BINARY_STEM_L2")
LR_model = Logistic_Regression_L2_SGD(n_iter=15,eta=0.1,l2=5, batch_size=10000)
LR_model.fit(np.load('Stored/Vectors/train_tfidf_stem.npy'), np.load('Stored/DocsVocab/y_train.npy'))
save_obj('Stored/Models/LR-tfidf-stem-L2',LR_model)
predictions = LR_model.predict(np.load('Stored/Vectors/test_tfidf_stem.npy'))
evaluate(predictions, y_test, "LOGISTIC_TFIDF_STEM_L2")

# %% [markdown]
# ### Logistic Regression Functions

# %%
def sigmoid(z):
    return 1/(1+ np.exp(-z))

def Cost(theta):
    z = 

def fit(X, y):
    y = r.reshape(-1,1)  
    theta = np.zeros((X.shape[1],1))
    
def predict(X, threshold=0.5):
    return np.where(sigmoid(X.dot(self.theta)) > = threshold,1,0)

def predict_prob(X):
    return sigmoid(X.dot(theta)

# %% [markdown]
# ### Other online reference

# %%
def get_top_k_predictions(model, X_test, k):
    
    #get probabilities instead of predicted lables
    probs = model.predict_proba(X_test)
    
    #get top k prdictions by prob (these are just index)
    best_n = np.argsort(probs, axis =1)[:,-k:]
    
    # Get Category of Prediction
    preds = [[model.classes_[predicted_cat] for predicted_cat in prediction] for prediction in best_n]
    
    # Reverse Categories (Descending order of importance)
    preds = [item[::-1] for item in preds]
    return preds

# %%
### Build Model

X_train =
y_train =

# from scikit package: Logistic Regression with built-in corss validation
scikit_log_reg = LogisticRegressionCV(cv = verbose =1, solver = 'liblinear', random_state = 0, C =5, penalty = '12', max_iter = 1000m)
model = scikit_log_reg.fit(X_train,y_train) 

X_test =
y_test =

# Get Top k prideictions
preds = get_top_k_predictions(model, X_test, top_k)

# get predicted value and ground truth into a list of list
eval_items = collect_preds(y_test, preds)

# Get evaluation number on Testset
accuracy = compute_accuracy(eval_items)
mrr_at_k = compute_mrr_at_k(eval_items)

# %% [markdown]
# ### Test Functions

# %%
def sigmoid(z):
    return np.exp(z)/(np.exp(z)+1)

# %%
sigmoid(0.5)
# Out:
# 0.6224593312018546

# %%
def Preprocess(data):
        # remove url
        pattern = r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'
        data = re.sub(pattern, '', data)
        
        # remove html special characters. 
        pattern = r'&[(amp)(gt)(lt)]+;'
        data = re.sub(pattern, '', data)
        
        # remove independent numbers.
        pattern = r' \d+ '
        data = re.sub(pattern, ' ', data)
        
        # lower case capitalized words.
        pattern = r'([A-Z][a-z]+)'
        def LowerFunc(matched):
            return matched.group(1).lower()
        data = re.sub(pattern, LowerFunc, data)
        
        # remove hashtags.
        pattern = r'[@#]([A-Za-z]+)'
        data = re.sub(pattern, '', data)
        return data

# %%
def GetTokens(data):
    # use tweet tokenizer
    tknzr = TweetTokenizer()
    tokens = tknzr.tokenize(data)

    # tokenize at each punctuation
    pattern = r'[A-Za-z]+\'[A-Za-z]+'
    for tk in tokens:
        if re.match(pattern, tk):
            subtokens = word_tokenize(tk)
            tokens.remove(tk)
            tokens = tokens + subtokens
    return tokens

# %%
# process tokens with setmming.
def WithStem(tokens):
    porter = PorterStemmer()  ####
    tokensStem = []
    for tk in tokens:
        tokensStem.append(porter.stem(tk))  ####
    return tokensStem

# %%
labelTrain = []
dataTrain = []
dataTrainStem = []
    
for root, ds, fs in os.walk('./tweet/train/'):
    for file in fs:
        fullname = os.path.join(root, file)
            
        # get the training label
        if "positve" in fullname:
            label = 1
        else: 
            label = 0
        data = open(fullname, encoding = "utf8").read()
        #print("Label_dataTrain", data)
            
        # Preprocess Labeled Data
        data = Preprocess(data)
        #print("Preprocess_Lable_dataTrain",data)

        # Get tokens for the data
        tokens = GetTokens(data)
        dataTrain.append(tokens)
        #print("Token_dataTrain[] =",tokens)

        # Getthe stemmed tokens for the data
        tokensStem = WithStem(tokens)
        dataTrainStem.append(tokensStem)
        print("Check Stemmed token data",tokensStem)
# Out:
# Check Stemmed token data ['so', 'I', 'still', 'need', 'to', 'stay', 'on', 'hold', '?', 'so', 'I', 'still', 'need', 'to', 'stay', 'on', 'hold', '?']
# Check Stemmed token data ['realli', '...', 'you', 'charg', 'me', '$', '25', 'to', 'check', 'a', 'bag', 'and', 'then', 'you', 'put', 'it', 'on', 'a', 'differ', 'flight', '...', 'still', 'have', 'my', 'bag', '!', '!', '!', 'do', "n't"]
# Check Stemmed token data ['.', 'thank', 'for', 'make', 'an', 'effort', '.', 'credit', 'where', 'credit', 'is', 'due', ':', 'flight', 'delay', 'hour', 'instead', 'of', 'hour', '.']
# Check Stemmed token data ['plz', 'advertis', 'wifi', 'if', 'not', 'gonna', 'work', 'thank', 'do', "n't", 'it', "'s"]
# Check Stemmed token data ['-', 'is', 'not', 'friendli', 'int', "'", 'l']
# Check Stemmed token data ['thank', 'for', 'a', 'subpar', 'travel', 'experi', 'and', 'not', 'even', 'over', 'yet', 'it', "'s"]
# Check Stemmed token data ['my', 'ex-boyfriend', 'pick', 'up', 'my', 'call', 'more', 'than', 'you', 'do', '!', 'flightedflight']
# Check Stemmed token data ['so', 'now', 'been', 'drive', 'across', 'dfw', 'for', 'over', '90min', '.', 'half', 'fuck', 'way', 'to', 'texarkana', '!', 'we', "'ve", 'that', "'s"]
# Check Stemmed token data ['when', 'tri', 'to', 'check-in', 'onlin', 'it', 'say', 'to', 'call', '...', 'now', 'been', 'on', 'hold', 'for', 'hour', '...', 'what', 'to', 'do', '?', 'I', "'ve"]
# Check Stemmed token data ['on', 'flight', 'vx399', 'head', 'to', 'LA', 'from', 'jfk', '-', 'dirtiest', 'VA', 'plane', 'I', 'have', 'ever', 'been', 'on', '.', 'sad', 'for', 'a', 'great', 'airlin', '.']
# Check Stemmed token data ['I', 'will', 'be', 'patient', 'as', 'your', 'agent', 'explain', 'how', 'you', 'have', 'me', 'book', 'on', 'a', 'new', 'flight', 'for', '6:18', 'when', 'that', 'plane', 'arriv', 'until', '6:07', 'doe', "n't"]
# Check Stemmed token data ['anyon', 'there', 'to', 'help', '?', 'still', 'on', 'hold', '...']
# Check Stemmed token data ['wast', 'time', 'at', 'baggag', 'claim', 'thank', 'to', 'your', 'dfw', 'ground', 'crew', 'who', 'check', 'my', 'bag', 'in', 'without', 'actual', 'check', 'for', 'space']
# Check Stemmed token data ['#611', 'from', 'jfk', 'to', 'la', 'still', 'delay', '?']
# Check Stemmed token data ['still', 'on', 'hold', '.', 'hour', 'and', 'minut', 'and', 'count', '.', 'platinum', '?', 'who', 'care', '?', 'problem', 'check', 'in', '?', 'who', 'care', '?']
# Check Stemmed token data ['thank', 'for', 'the', 'respons', '.', 'I', 'know', 'not', 'your', 'fault', '...', 'but', 'im', 'in', 'ord', 'in', 'T5', 'and', 'hungri', 'if', 'you', 'want', 'to', 'stop', 'by', '✈', '️', '✌', '️', 'it', "'s"]
# Check Stemmed token data ['you', 'may', 'think', 'joke', 'or', 'blow', 'it', 'out', 'of', 'proport', 'but', 'the', 'last', 'unit', 'flight', 'have', 'been', 'delay', 'or', 'significantli', 'late', 'flight', '.', 'I', "'m"]
# Check Stemmed token data ['delay', 'for', 'two', 'hour', 'at', 'ord--cdg', 'the', 'one', 'time', 'I', 'need', 'to', 'be', 'there', 'to', 'catch', 'a', 'train', '...', '😒']
# Check Stemmed token data ['I', 'submit', 'a', 'complaint', 'via', 'that', 'link', 'in', 'dec', '.', 'follow', 'up', 'in', 'jan', '.', 'never', 'heard', 'back', '!']
# Check Stemmed token data ['we', 'have', 'been', 'advis', 'to', 'turn', 'thi', 'issu', 'over', 'to', 'the', 'polic', 'due', 'to', 'the', 'sexual', 'assult', 'thank', 'you', 'for', 'allow', 'that', 'ON', 'your', 'plane', '!']
# Check Stemmed token data ['due', 'to', 'an', 'appar', 'water', 'issu', 'that', 'check', 'out', 'fine', 'dure', 'the', 'check', 'my', 'husband', 'and', 'I', 'alreadi', 'had', 'to', 'deal', 'with', 'our', 'first']
# Check Stemmed token data ['you', 'guy', 'should', 'stop', 'do', 'servic', 'in', 'denver', 'horribl', 'I', 'get', 'stuck', 'here', 'everi', 'time', '!', 'been', 'here', 'almost', '24hr', 'it', "'s", 'I', "'ve"]
# Check Stemmed token data ['need', 'to', 'learn', 'how', 'to', 'treat', 'peopl', 'with', 'respect', 'and', 'just', 'a', 'littl', 'digniti', '.']
# Check Stemmed token data ['so', 'you', 'understand', 'whi', 'resort', 'to', 'twitter', ':', 'no', 'help', 'avail', 'at', 'gate', 'while', 'thi', 'occur', 'or', 'by', 'phone', 'afterward', '.', 'I', "'m"]
# Check Stemmed token data ['your', 'websit', 'allow', 'me', 'to', 'post', 'the', 'requir', 'document', 'i', 'keep', 'get', '*', '*', 'were', 'have', 'technic', 'difficulti', '*', '*', 'wo', "n't"]
# Check Stemmed token data ['they', 'book', 'me', 'for', 'tomorrow', '.', '$', '250', 'higher', '.', 'my', '1st', 'reserv', 'is', 'pgfryz', '.', 'get', 'me', 'on', 'standbi', 'list', 'tonight', 'would', 'help', '.', 'it', "'s"]
# Check Stemmed token data ['you', 'hr', 'ago', 'at', 'your', 'request', '.', 'no', 'respons', 'to', 'be', 'found', '...', 'just', 'like', 'my', 'bag', '.', 'DM', "'d"]
# Check Stemmed token data ['ok', '.', 'thing', 'happen', '.', 'just', 'veri', 'frustrat', 'when', 'you', 'have', 'to', 'chang', 'your', 'schedul', '.', 'see', 'you', 'tomorrow', 'for', 'a', 'new', 'reschedul', 'flight', '.', 'it', "'s"]
# Check Stemmed token data ['I', 'know', 'your', 'polici', '.', 'just', 'ask', 'for', 'a', 'littl', 'kind', 'due', 'to', 'extenu', 'circumst', '.']
# Check Stemmed token data ['ye', '-', 'with', 'extra', '$', '77', '.', 'I', 'wonder', 'what', 'are', 'you', 'go', 'yo', 'loos', 'if', 'there', 'is', 'room', '.']
# Check Stemmed token data ['I', 'have', 'been', 'tri', 'to', 'speak', 'with', 'an', 'agent', 'the', 'whole', 'day', 'about', 'my', 'cancel', 'flightl', 'flight', 'what', 'I', 'can', 'do', '?']
# Check Stemmed token data ['hate', 'when', 'I', 'get', 'bump', 'out', 'of', 'the', 'seat', 'select', '(', 'empti', 'row', ')', 'and', 'move', 'to', 'anoth', 'seat', '(', 'non-empti', ')', '.', '#1k', '803', '!', 'I', "'ve"]
# Check Stemmed token data ['hold', 'for', 'min', 'a', 'coupl', 'of', 'ring', 'then', '"', 'mailbox', 'ha', 'not', 'been', 'set', 'up', 'yet', '.', '"', 'custom', 'servic', 'forward', 'to', 'their', 'cell', 'phone', '?', "c'mon"]
# Check Stemmed token data [':', '"', 'left', 'gate', 'minut', 'earli', '.', '"', 'my', 'thought', ':', '"', 'that', 'count', 'if', 'you', 'sit', 'on', 'the', 'tarmac', 'for', 'a', 'half', 'hour', '.', '"', 'doe', "n't"]
# Check Stemmed token data ['no', 'no', 'no', 'you', 'DM', 'me', 'I', 'pay', 'you', 'money', 'and', 'you', 'want', 'to', 'me', 'to', 'reach', 'out', 'to', 'you', 'for', 'help', '?', 'how', 'about', 'the', 'other', 'way', 'around']
# Check Stemmed token data ['we', 'had', 'to', 'sit', 'in', 'the', 'airport', 'a', 'long', 'periolodicli', 'time', '.', 'the', 'plane', 'were', 'nasti']
# Check Stemmed token data ['believ', 'how', 'mani', 'pay', 'custom', 'you', 'left', 'high', 'and', 'dri', 'with', 'no', 'reason', 'for', 'flight', 'cancel', 'flightlat', 'monday', 'out', 'of', 'bdl', '!', 'wow', '.', 'ca', "n't"]
# Check Stemmed token data ['an', 'overzeal', 'stewardess', 'prevent', 'us', 'from', 'bring', 'in', 'a', 'car', 'seat', '!', '!']
# Check Stemmed token data ['I', 'will', 'be', 'stun', 'if', 'my', 'bag', 'are', 'in', 'hartford', 'with', 'me', '.', 'the', 'ord', 'ground', 'crew', 'onli', 'had', 'an', 'hour', 'to', 'move', 'my', 'bag', 'yard']
# Check Stemmed token data ['no', 'one', 'answer', 'phone', 'delay', '/', 'cancel', 'flightl', 'flight', '.', 'rude', 'employe', '.', 'you', 'onli', 'get', '(', 'sorri', 'we', 'apolog', ')', 'blah', 'blah', 'blah', '.', 'bad', 'I', "'m"]
# Check Stemmed token data ['on', 'one', 'of', 'your', '757-300', 'between', 'jfk', 'and', 'lax.when', 'r', 'u', 'upgrad', 'plane', '?', 'plane', 'ha', 'no', 'screenslousi', 'seat', 'and', 'in', 'unitedfirst', '.', 'I', "'m", 'that', "'s"]
# Check Stemmed token data ['need', 'help', 'with', 'a', 'flight', '.', 'weather', '+', 'funer', '=', 'tough', 'combin', '.', 'on', 'hold', 'for', 'over', 'an', 'hour', '.', 'pleas', '?']
# Check Stemmed token data ['the', 'highlight', 'of', 'be', 'delay']
# Check Stemmed token data ['current', 'bug', 'on', 'websit', 'show', '‘', 'select', 'departur', 'citi', '’', 'when', 'select', 'destin', 'citi']
# Check Stemmed token data ['ani', 'solut', '?']
# Check Stemmed token data ['I', 'did', 'but', 'it', 'help', '..', 'believ', 'you', 'take', 'full', 'fare', 'for', 'first', 'class', 'and', 'gave', 'away', 'to', 'platinum', 'member', '..', 'profit', '?', 'wo', "n't", 'ca', "n't", 'would', "n't"]
# Check Stemmed token data ['while', 'aggrav', '-', 'baggag', 'fee', 'disappear', 'now', 'that', 'ga', 'price', 'have', 'drop', '?', 'I', "'m", 'should', "n't"]
# Check Stemmed token data ['here', 'we', 'go', 'again', '106', '"', 'plane', 'not', 'readi', '"', '.', 'are', 'we', 'go', 'to', 'find', 'the', 'crew', 'run', 'out', 'of', 'time', 'again', 'like', 'last', 'night']
# Check Stemmed token data ['as', 'a', 'gold', 'dividend', 'member', 'whi', 'I', 'get', 'anyon', 'on', 'phone', 'to', 'handl', 'my', 'cancel', 'flight', 'american', 'flight', 'tonight', '😡', 'ca', "n't"]
# Check Stemmed token data ['no', 'updat', 'on', 'anyth', '!', 'all', 'we', 'know', 'is', 'there', 'is', 'an', 'issu', 'with', 'the', 'front', 'wheel', 'be', 'lock', '.']
# Check Stemmed token data ['thank', 'you', 'for', 'blow', 'my', 'vacat', '.', 'get', 'me', 'anywher', 'today', 'to', 'make', 'my', 'reserv', 'and', 'also', 'lost', 'bag', 'of', 'mine', '!', 'could', "n't"]
# Check Stemmed token data ['5.5', 'hr', 'late', 'flightr', 'and', 'you', 'still', 'figur', 'it', 'out', '.', 'random', 'text', 'updat', '.', '3728', 'ca', "n't"]
# Check Stemmed token data ['if', 'someon', 'had', 'bother', 'to', 'inform', 'us', 'that', 'the', 'airport', 'close', 'that', 'would', 'have', 'help', '.']
# Check Stemmed token data ['ur', '"', 'respons', '"', 'wa', ':', 'my', '"', 'inconveni', 'wa', 'of', 'no', 'matter', '.', '"', 'U', 'want', 'me', 'sit', 'for', 'xtra', 'night', 'in', 'the', 'citi', 'w', '/', 'out', 'comp', '!']
# Check Stemmed token data ['now', 'after', 'an', 'hour', 'on', 'the', 'plane', 'and', 'know', 'of', 'a', 'maint', 'issu', 'ahead', 'of', 'time', 'they', 'just', 'announc', 'anoth', 'min', '.', 'Y', 'r', 'we', 'on', 'plane', '?']
# Check Stemmed token data ['check', 'in', 'your', 'site', 'look', 'like', 'thi', 'everi', 'time', 'it', 'load', 'ca', "n't"]
# Check Stemmed token data ['your', 'respons', 'could', 'have', 'made', 'all', 'the', 'differ', '.', 'it', 'could', 'have', 'made', 'the', 'situat', 'better', '.', 'NO', 'trust', '...', 'get', 'lost', 'like', 'my', 'bag', '.']
# Check Stemmed token data ['-', 'I', 'call', 'and', 'they', 'solv', 'the', 'flight', 'cancel', 'flightlat', 'issu', 'in', '15minut', '.', 'may', 'be', 'ask', 'them', 'how', 'to', 'do', 'it', '?']
# Check Stemmed token data ['custom', 'dumb', '.', 'these', 'revenu', 'base', 'program', 'will', 'hurt', 'everyon', '.', 'not', 'gonna', 'save', 'money', 'like', 'you', 'think', 'are', "n't"]
# Check Stemmed token data ['becaus', 'of', 'the', 'horrif', 'flight', 'experi', 'you', 'guy', 'have', 'made', 'me', 'never', 'want', 'to', 'fli', 'on', 'an', 'airplan', 'everi', 'again', '!', '!', '!']
# Check Stemmed token data ['thank', 'you', 'for', 'your', 'repli', '.', 'my', 'frustrat', 'is', 'that', 'spend', 'a', 'upgrad', 'just', 'put', 'you', 'on', 'a', 'wait', 'list', '.']
# Check Stemmed token data ['after', 'appli', 'my', 'new', 'tag', 'she', 'left', 'my', 'bag', 'on', 'the', 'ground', 'rather', 'than', 'load', 'on', 'the', 'convey', 'belt', '..', 'I', 'had', 'to', 'walk', 'back', 'yard']
# Check Stemmed token data ['wa', 'no', 'one', 'between', 'the', 'scan', 'and', 'insid', 'the', 'plane', '.', 'I', 'just', 'ask', 'the', 'peopl', 'in', 'line', 'around', 'me', 'where', 'the', 'plane', 'wa', 'go']
# Check Stemmed token data ['is', 'it', 'me', 'or', 'is', 'your', 'websit', 'down', '?', 'btw', 'your', 'new', 'websit', 'a', 'great', 'user', 'experi', '.', 'time', 'for', 'anoth', 'redesign', '.', 'is', "n't"]
# Check Stemmed token data ['my', 'flight', 'land', 'min', 'but', 'we', 'are', 'be', 'told', 'to', 'stay', 'on', 'the', 'plane', 'pull', 'up', 'to', 'the', 'gate', 'have', 'littl', 'to', 'no', 'inform', '.', 'have', "n't"]
# Check Stemmed token data ['bag', 'fli', 'free', '..', 'just', 'not', 'to', 'where', 'go', '.', 'you', "'re"]
# Check Stemmed token data ['-', 'flight', 'cancel', 'flightl', '.', 'hr', 'at', 'airport', 'to', 'book', 'a', 'new', 'one', 'for', '$', '95', '.', 'just', 'got', 'two', 'invoic', 'for', 'the', 'flight', 'each', 'for', 'approx', '$', '300', '.', 'realli', '?', '!']
# Check Stemmed token data ['you', 'board', 'a', '630a', 'flight', 'and', 'then', 'cancel', 'flight', 'it', 'becaus', 'it', 'have', 'a', 'pilot', '?', 'now', 'I', 'miss', 'my', 'meet', 'atlanta', 'becaus', 'someon', 'slept', 'in', '?', 'doe', "n't"]
# Check Stemmed token data ['-', 'thank', 'for', 'the', '5', '+', 'hour', 'flight', 'from', 'pit', 'to', 'phx', 'with', 'zero', 'entertain', '.', 'guess', 'whi', 'I', 'have', 'a', 'quarter', 'million', '+', 'mile', 'on', 'delta']
# Check Stemmed token data ['get', 'new', 'plane', 'then', '.', 'got', 'on', 'thi', 'plane', 'at', '7:50', 'it', '10:20', 'now', 'and', 'still', 'on', 'tarmac', '.', 'how', 'ru', 'go', 'to', 'compens', 'me', 'for', 'thi', '?']
# Check Stemmed token data ['on', 'your', 'flight', 'jfk', 'to', 'PR', '.', 'they', 'got', 'the', 'door', 'open', 'on', 'thi', 'frigid', 'temperatur', '.']
# Check Stemmed token data ['go', 'on', 'with', 'flight', 'and', 'how', 'mani', 'free', 'trip', 'will', 'I', 'get', 'from', 'thi', 'epic', 'inconveni', 'what', "'s"]
# Check Stemmed token data ['if', 'go', 'to', 'cancel', 'flight', 'flight', 'today', 'do', 'everyon', 'a', 'favor', 'and', 'get', 'on', 'it', 'now', '.', 'stall', 'the', 'inevit', '.', 'you', "'re", 'do', "n't"]
# Check Stemmed token data ['4/9', '/', '14', 'I', 'need', 'to', 'fli', 'from', 'gsp', 'to', 'dsm', 'but', 'claim', 'no', 'sched', '.', 'avail', '.', 'I', 'can', 'book', 'separ', 'but', 'whi', 'not', 'togeth', '?', 'there', "'s"]
# Check Stemmed token data ['tri', 'to', 'book', 'a', 'flight', 'on', 'hold', '-', 'get', 'through', 'to', 'a', 'repres', 'on', 'the', 'phone', '-', 'advic', '?', 'ca', "n't"]
# Check Stemmed token data ['yeah', 'not', 'help', '.', 'have', 'my', 'bag', 'ship', 'to', 'the', 'correct', 'citi', 'the', 'first', 'time', 'probabl', 'would', 'have', 'help', '.', 'that', "'s"]
# Check Stemmed token data ['den', '-', 'dfw', '.', 'we', 'want', 'to', 'be', 'ticket', 'on', 'a', 'new', 'flight', 'just', 'refund', 'for', 'our', 'cancel', 'flight', 'flight', '.', 'do', "n't"]
# Check Stemmed token data ['so', 'you', 'strand', 'my', 'bag', 'in', 'philli', 'last', 'sat', 'and', 'strand', 'me', 'in', 'philli', 'thi', 'sat', '.', 'thank', 'for', 'the', 'bullshit', '.']
# Check Stemmed token data ['is', 'it', 'customari', 'to', 'upgrad', 'a', 'flight', 'attend', 'in', 'uniform', 'vs', 'passeng', '?', 'one', 'is', 'in', '1B', 'on', 'flt', 'now', 'to', 'iah']
# Check Stemmed token data ['the', 'wichita', 'fall', 'airport', 'is', 'the', 'worst', 'will', 'never', 'fli', 'in', 'or', 'out', 'again', '.', 'unknowledg', 'staff', '.']
# Check Stemmed token data ['whoa', '!', 'no', 'tag', 'and', 'you', 'still', 'saw', 'my', 'tweet', '.', 'flight', 'jfk', 'to', 'chicago', '.', 'tri', 'to', 'get', 'home', 'to', 'see', 'my', 'littl', 'brother', 'wrestl', '!']
# Check Stemmed token data ['my', 'credit', 'card', 'wa', 'charg', 'on', 'the', 'transact', 'when', 'I', 'wa', 'told', 'it', 'would', 'not', 'be', '.', 'if', 'the', 'charg', 'goe', 'through', 'I', 'will', 'be', 'contact', 'you', '.']
# Check Stemmed token data ['le2v9d', 'pnr', 'number', 'flight', '.', 'the', 'first', 'leg', 'is', 'cancel', 'flightl', 'due', 'to', 'bad', 'weather', 'in', 'iatanbul', '.', 'how', 'can', 'i', 'make', 'a', 'reflight', 'book', 'problem']
# Check Stemmed token data ['just', 'sat', 'on', 'a', 'plane', 'for', 'hour', 'in', 'dull']
# Check Stemmed token data ['nope', '.', 'thi', '8:', '45am', 'flight', 'is', 'now', 'not', 'leav', 'until', 'almost', '5pm', '.', '5', '!', 'I', 'believ', 'I', 'paid', 'money', 'for', 'thi', '.', 'ca', "n't"]
# Check Stemmed token data ['they', 'help', 'me', 'at', 'the', 'baggag', 'servic', 'desk', '.', 'said', 'bc', 'tsa', 'screen', 'wa', 'down', 'in', 'fll', 'not', 'all', 'bag', 'made', 'it', 'but', 'bag', 'will', 'be', 'in', 'ewr', '@', '12']
# Check Stemmed token data ['been', 'on', 'hold', 'for', 'over', 'and', 'hour', 'now', '.']
# Check Stemmed token data ['I', 'want', 'to', 'be', 'too', 'whini', '.', 'we', 'accommod', 'sever', 'passeng', 'whose', 'earlier', 'flight', 'wa', 'cancel', 'flightl', '.', 'our', 'flight', 'wa', 'veri', 'long', '.', 'do', "n't"]
# Check Stemmed token data ['-', 'hand', 'a', 'slip', 'of', 'papersaid', 'to', 'call', '1800', '#', '.', 'have', 'call', '2x', '/', 'day', 'tri', 'to', 'get', 'it', 'sent', 'still', '@', 'layov', 'airport.hav', 'that', 'ref', '#', 'tho', '.']
# Check Stemmed token data ['roger', 'wilco', '.']
# Check Stemmed token data ['I', 'did', 'not', 'get', 'ani', 'compens', 'after', 'cancel', 'flight', 'my', 'departur', 'twice', 'and', 'made', 'me', 'miss', 'my', 'own', 'wed', '.']
# Check Stemmed token data ['wa', 'go', 'for', 'the', 'weekend', 'for', 'birthday', 'so', 'no', 'point', 'in', 'reflight', 'book', 'problem', '.', 'friend', "'s"]
# Check Stemmed token data ['delay', 'on', 'the', 'way', 'to', 'puerto', 'rico', 'and', 'delay', 'on', 'the', 'way', 'back', 'to', 'new', 'york', 'thi', 'is', 'disgrac']
# Check Stemmed token data ['I', 'wa', 'eventu', 'given', 'a', 'flight', 'to', 'memphi', 'but', 'onli', 'after', 'I', 'wa', 'taken', 'off', 'my', 'origin', 'flight', 'bc', 'I', 'wa', 'check', 'in', 'as', 'my', 'father']
# Check Stemmed token data ['-', 'I', 'am', 'platinum', '.', 'I', 'am', 'fli', 'usair', 'and', 'they', 'have', 'strand', 'me', 'in', 'clt', '.', 'not', 'answer', 'phone', '.', 'did', 'not', 'rebook', 'me', '.', 'pleas', 'help', '?']
# Check Stemmed token data ['how', 'do', 'you', 'have', 'a', 'schedul', 'flight', 'with', 'NO', 'crew', '?', 'is', 'there', 'a', 'compet', 'person', 'work', 'at', 'thi', 'airlin', '?']
# Check Stemmed token data ['taylor', '.', 'U', 'gotta', 'love', 'swa', 'respons', 'at', 'the', 'least', 'huh', '?']
# Check Stemmed token data ['pl', 'find', 'my', 'bag', 'I', 'need', 'get', 'home', '!', 'veri', 'frustrat', '.', 'hope', 'my', 'bag', 'is', 'somewher', 'in', '_njairport', '.', 'leav', 'the', 'w', '/', 'o', 'my', 'luggag', '.']
# Check Stemmed token data ['my', 'husband', 'is', 'suppos', 'to', 'fli', 'rdu', 'to', 'iad', 'then', 'iad', 'to', 'fra', 'leav', 'in', 'hour', '.', 'you', 'cancel', 'flight', 'hi', 'flight', 'and', 'a', '1hr', 'wait', 'on', 'phone', 'there', "'s"]
# Check Stemmed token data ['no', '.', 'had', 'to', 'cancel', 'flight', 'my', 'trip', '.', 'instead', 'of', 'a', '$', '25', 'futur', 'trip', 'voucher', 'a', '$', '25', 'drink', 'coupon', 'been', 'better', '!', 'would', "'ve"]
# Check Stemmed token data ['-', 'your', 'site', 'seem', 'a', 'littl', 'wonk', 'right', 'now', '.', 'may', 'want', 'to', 'have', 'a', 'look', '.', 'tri', 'on', 'two', 'browser', '.', 'no', 'css', '?']
# Check Stemmed token data ['it', 'wa', 'me', 'who', 'had', 'the', 'problem', 'won', 'flight', 'ua', '1580', '.', 'I', 'call', 'and', 'rebook', 'myself', 'found', 'my', 'own', 'hotel', 'and', 'taxi']
# Check Stemmed token data ['flight', '#1641', 'delay', 'from', 'pos-mia', 'miss', '#2214', 'mia', '-', 'atl', 'need', 'seat', 'on', 'last', 'flight', 'to', 'atl', '.']
# Check Stemmed token data ['my', 'bag', 'is', 'miss', 'from', 'land', 'over', 'hour', 'ago', '.', 'help', '!']
# Check Stemmed token data ['I', 'paid', 'for', 'inflight', 'wifi', 'onli', 'for', 'it', 'not', 'to', 'work', '.', 'download', 'speed', 'wa', '0.21', 'mbp', 'I', 'end', 'up', 'watch', 'the', 'free', 'TV', 'instead', '.']
# Check Stemmed token data ['check', 'on', 'what', '?', 'our', 'broken', 'tablet', '!', 'see', 'attach', 'pictur', '.']
# Check Stemmed token data ['had', 'a', 'veri', 'rude', 'gate', 'agent', 'at', 'bwi', 'tonight', 'gate', 'B8', 'after', 'a', '6.5', 'hr', 'delay', 'for', 'flight', '1172', '.', 'I', 'think', 'a', 'littl', 'train', 'is', 'in', 'order', '.']
# Check Stemmed token data ['anoth', 'gener', 'respons', 'guy', '?', 'cmon', '.', 'terribl', '.', 'how', 'about', 'an', 'actual', 'help', 'person', '?', 'not', 'all', 'the', 'rude', 'employe', 'at', 'lax', 'you', "'re"]
# Check Stemmed token data ['befor', 'departur', 'while', 'peopl', 'who', 'are', 'delay', 'get', 'up', 'to', '$', '200', 'to', 'compens', 'their', 'time', '..']
# Check Stemmed token data ['leav', 'over', 'minut', 'late', 'flight', '.', 'no', 'warn', 'or', 'commun', 'until', 'we', 'were', 'minut', 'late', 'flight', '.', 'call', 'shitti', 'custom', 'svc', 'that', "'s"]
# Check Stemmed token data ['termin', 'E', 'in', 'miami', 'is', 'still', 'the', 'worst', 'most', 'smelli', 'airport', 'ever', '.', 'thank', 'for', 'noth', '.']
# Check Stemmed token data ['not', 'cancel', 'flightl', '#837', 'becaus', 'you', 'want', 'to', 'put', 'us', 'in', 'a', 'hotel', 'for', 'night', 'is', 'our', 'guess', 'do', "n't"]
# Check Stemmed token data ['but', 'expect', 'no', 'help', 'from', '-', '-', '.', 'our', 'flt', 'wa', 'canx', 'at', 'the', 'last', 'minut', 'for', '"', 'weather', '.', '"', 'we', 'flew', 'home', 'on', 'weatherless', '.']
# Check Stemmed token data ['when', 'will', 'email', 'address', '/', 'usernam', 'sign-on', 'be', 'avail', '?', 'been', 'a', 'while', '.', 'it', "'s"]
# Check Stemmed token data ['you', 'guy', 'charg', 'me', '$', '100', 'to', 'reschedul', 'a', 'flight', 'that', 'wa', 'then', 'cancel', 'flight', 'and', 'are', 'now', 'refus', 'to', 'refund', 'it', '.', 'the', 'deal', '?', 'what', "'s"]
# Check Stemmed token data ['there', 'are', 'onli', 'hour', 'to', 'cancel', 'flight', 'or', 'chang', 'itinerari', 'book', 'onlin', 'and', 'that', 'hour', 'is', 'just', 'about', 'over', '.', 'imposs', 'scenario']
# Check Stemmed token data ['.', 'advis', 'ga', 'and', 'pilot', 'of', 'my', 'flight', '.', 'too', 'bad', 'no', 'one', 'took', 'action', '.']
# Check Stemmed token data ['I', 'let', 'a', 'crew', 'member', 'know', 'everi', 'time', 'thi', 'happen', '.', 'which', 'is', 'most', 'of', 'the', 'time', '.']
# Check Stemmed token data ['I', 'wa', 'on', 'hold', 'for', 'minut', 'no', 'one', 'know', 'how', 'to', 'win', 'these', 'ticket', 'that', 'still', 'hand', 'out', '?', 'you', "'re"]
# Check Stemmed token data ['you', 'are', 'the', 'worst', 'airlin', 'in', 'the', 'world', '!', 'from', 'your', 'crap', 'websit', 'to', 'your', 'worthless', 'app', 'to', 'your', 'late', 'flight', 'flight', '.', 'you', 'suck', '!', 'just', 'shut', 'down', '.']
# Check Stemmed token data ['*', 'fight', 'air', '*']
# Check Stemmed token data ['land', 'at', 'mco', 'befor', '9am', 'and', 'still', 'have', 'my', 'bag', '.', 'you', 'were', 'suppos', 'to', 'give', 'it', 'to', 'magic', 'express', 'thi', 'AM', '.', 'I', 'am', 'livid', '!', 'do', "n't", 'disney', "'s"]
# Check Stemmed token data ['are', 'you', 'tri', 'to', 'break', 'a', 'world', 'record', 'for', 'most', 'delay', 'flight', 'in', 'a', 'year', '?']
# Check Stemmed token data ['okay', 'I', 'understand', 'a', 'delay', 'one', 'way', '.', 'but', 'both', 'way', '?', "c'mon"]
# Check Stemmed token data ['hv', 'wound', 'vet', 'stuck', 'in', 'chi', '.', 'travel', 'to', 'NY', 'heal', '.', 'need', 'fli', 'ny', 'late', 'flightst', 'AM', 'by', '2', 'catch', 'intl', 'flt', '.', 'help', '!', 'he', "'s"]
# Check Stemmed token data ['did', 'somebodi', 'say', 'flight', 'upgrad', '?']
# Check Stemmed token data ['flight', 'delay', 'at', 'jfk', 'hour', 'then', 'hour', 'then', '8.5', 'hour', '?', 'now', 'back', 'to', 'hour', 'with', 'no', 'explan', 'or', 'apolog', '?', 'it', "'s"]
# Check Stemmed token data ['third', 'you', 'lost', 'her', 'bag', 'after', 'min', 'of', 'be', 'on', 'hold', 'you', 'told', 'her', 'she', 'would', '"', 'eventu', 'get', 'her', 'bag', '"', 'complet', 'unaccept']
# Check Stemmed token data ['you', 'realli', 'should', 'clean', 'the', 'food', 'and', 'coffe', 'stain', 'off', 'of', 'the', 'area', 'around', 'the', 'seat', 'when', 'new', 'passeng', 'come', 'aboard', '.', 'gross', '!']
# Check Stemmed token data ['they', 'tri', 'to', 'have', 'us', 'tow', '.', 'do', 'you', 'think', 'be', 'fli', 'out', 'of', 'your', 'termin', 'again', '?', 'risk', 'of', '$', '75', 'fine', 'from', 'corrupt', 'polic', 'offici', 'I', "'ll"]
# Check Stemmed token data ['.', 'yet', 'anoth', 'delay', '/', 'miss', 'connect', '...', 'and', 'your', 'custom', 'servic', 'ha', 'an', 'attitud', 'with', 'me', '?', 'wow', '.']
# Check Stemmed token data ['not', 'let', 'me', 'DM', '.', '#', 'is', 'fsz', '4yo']
# Check Stemmed token data ['undermin', 'the', 'intellig', 'of', 'custom', 'by', 'ignor', 'their', 'complaint', 'with', 'their', 'copi', 'and', 'past', 'can', 'respons']
# Check Stemmed token data ['...', 'I', 'want', 'my', 'bag', 'off', 'flight', 'what', 'do', 'I', 'do', 'now', '?']
# Check Stemmed token data ['8929', 'sorri', 'unit', 'abl', 'to', 'keep', 'it', 'word', "'", 'cuz', 'their', 'IT', 'is', 'total', 'inadequ', 'but', 'they', 'still', 'say', 'a', 'custom', 'fault', '!', 'I', "'m", 'is', "n't", 'it', "'s"]
# Check Stemmed token data ['thx', 'for', 'take', 'my', '$', '600', 'for', 'a', '1way', 'then', 'cancel', 'flightl', '1st', 'flt', 'delay', '2nd', 'flt', 'and', 'u', 'top', 'it', 'off', 'by', 'lose', 'my', 'one', 'piec', 'of', 'luggag']
# Check Stemmed token data ['too', 'bad', 'you', 'say', 'it', 'take', 'to', 'day', 'via', 'your', 'confirm', 'email', '.', 'when', 'I', 'inquir', 'after', 'week', 'you', 'claim', 'to', 'week', '!']
# Check Stemmed token data ['I', 'have', 'a', 'flight', 'voucher', '/', 'confirm', 'code', 'but', 'there', 'is', 'no', 'where', 'for', 'me', 'to', 'enter', 'it', 'on', 'your', 'checkout', 'page', 'while', 'flight', 'book', 'problem', '.', 'pl', 'help']
# Check Stemmed token data ['still', 'irrit', 'that', 'our', 'well', 'plan', 'and', 'book', 'return', 'wa', 'mess', 'with', 'with', 'no', 'warn', '.']
# Check Stemmed token data ['phone', 'rep', '.', 'none', 'could', 'see', 'I', 'wa', 'rebook', 'so', 'miss', 'that', 'flight.told', 'to', 'go', 'standbi', 'for', 'a', 'nonexist', 'late', 'flightr', 'flight', '.', 'did', 'I', 'hurt', 'you', '?']
# Check Stemmed token data ['pleas', 'explain', 'whi', 'I', 'need', 'to', 'pay', 'bag', 'fee', 'twice', 'equal', '$', '1200', 'becaus', 'a', 'delay', 'flight', 'result', 'in', 'bag', 'be', 'recheck', 'overnight', '?']
# Check Stemmed token data ['haha', 'I', 'did', '.', 'they', 'said', 'it', 'their', 'fault', 'somehow', '?', 'you', 'guy', 'r', 'a', 'joke', 'wa', "n't"]
# Check Stemmed token data ['you', 'hung', 'up', 'on', 'me', 'again', '.']
# Check Stemmed token data ['realli', '?', 'hr', 'delay', 'gate', 'chang', 'you', 'board', 'us', 'sent', 'us', 'back', 'up', 'board', 'us', 'again', '.', 'chang', 'our', 'flight', '.', 'can', 'we', 'go', 'now', '?', 'wo', "n't"]
# Check Stemmed token data ['whi', '?', '😒', 'RT', 'our', 'on', 'fleek', '.', 'fleet', "'s"]
# Check Stemmed token data ['flight', 'is', 'a', 'freak', 'nightmar', 'tonight']
# Check Stemmed token data ['thank', 'you', 'for', 'credit', '.', 'howev', ';', 'I', 'submit', 'complaint', 'about', 'the', 'properti', 'on', 'vacat', 'packag', '.', 'hope', 'you', 'listen', '!']
# Check Stemmed token data ['how', 'can', 'you', 'not', 'know', 'the', 'weight', 'of', 'our', 'plane', 'after', 'us', 'sit', 'on', 'the', 'plane', 'for', '2.5', 'hr', '?', 'not', 'convinc', 'your', 'compani', 'is', 'safe', 'for', 'flt', '.']
# Check Stemmed token data ['I', 'find', 'thi', 'text', 'funni', 'consid', 'we', 'are', 'still', 'sit', 'here', 'becaus', 'seat', 'need', 'to', 'be', 'chang', 'out', '.']
# Check Stemmed token data ['rebookedarriv', 'hour', 'late', 'flightr', '.', 'last', 'year', 'hr', 'to', 'san', 'diego', 'and', 'the', 'no', 'inflight', 'entertain', '!']
# Check Stemmed token data ['I', 'knew', 'the', '3-4', 'hour', 'sound', 'odd', ';', 'miss', 'a', 'flight', 'we', 'hit', 'jfk', 'an', 'hour', 'earli', 'for', 'and', 'your', 'gate', 'attend', 'told', 'us', '3-4', ':(']
# Check Stemmed token data ['understood', '...', 'but', 'could', 'I', 'go', 'and', 'put', 'myself', 'on', 'the', 'standbi', 'list', 'hour', 'prior', 'to', 'my', 'flight', '?']
# Check Stemmed token data ['I', 'know', 'but', 'I', 'want', 'to', 'pass', 'it', 'along', '.', 'not', 'good', 'for', 'the', '"', 'T5', 'experi', '"', 'esp', 'for', 'someon', 'who', 'fli', '2-3', 'time', 'a', 'month', '.']
# Check Stemmed token data ['where', 'we', 'all', 'get', 'on', 'the', 'same', 'page', '.', 'cancel', 'flight', 'it', 'min', 'ago', '.', 'help', 'flight', 'from', 'to', 'mco', '?', 'that', "'s"]
# Check Stemmed token data ['our', 'ft', 'tu', '/', 'dfw', '(', 'w', '/', 'cx', 'to', 'lga', ')', 'tomorrow', 'cancel', 'flight', 'hr', 'so', 'far', 'wait', 'for', 'call', 'back', '.', 'what', 'should', 'we', 'do', '?', 'need', 'to', 'get', 'to', 'nyc']
# Check Stemmed token data ['no', 'you', 'care', 'less', '.', 'whi', 'their', 'custom', 'servic', 'is', 'run', 'by', 'bot', 'could', "n't", 'that', "'s"]
# Check Stemmed token data ['appar', 'mechan', 'had', 'to', 'be', 'flown', 'in', 'to', 'fix', 'some', 'plane', '...', 'not', 'the', 'most', 'assur', 'sign']
# Check Stemmed token data ['not', 'at', 'all', '.', 'rerout', 'to', 'snowi', 'bwi', 'been', 'tri', 'to', 'figur', 'out', 'how', 'to', 'get', 'out', 'of', 'here', '.', 'now', 'deal', 'with', 'more', 'baggag', 'troubl', '.']
# Check Stemmed token data ['I', 'appreci', 'the', 'immedi', 'offer', 'but', 'suspect', 'it', 'is', 'more', 'long-term', 'issu', '/', 'not', 'simpl', 'fix', '.', 'also', 'ski', '/', 'bootbag', 'polici', 'is', 'awkward', 'at', 'best']
# Check Stemmed token data ['hello', '-', 'been', 'on', 'hold', 'for', 'extrem', 'long', 'time', '.', 'have', 'confirm', '#', 'get', 'board', 'pass', '.', 'have', 'tri', 'numer', 'time', '!', '!', 'ca', "n't"]
# Check Stemmed token data ['still', 'wait', 'for', 'anoth', 'crew', 'member', '.']
# Check Stemmed token data ['part', ':', 'wa', 'at', 'bag', 'drop', 'insert', 'my', 'jetblu', 'cc', 'print', 'pass', '.', 'agent', 'stand', 'in', 'front', 'of', 'me', 'refus', 'to', 'print', 'my', 'pass', 'here', "'s", 'did', "n't"]
# Check Stemmed token data ['.', 'you', 'neglect', 'to', 'mention', 'the', '$', '200', 'fee', 'per', 'ticket', '.', 'I', 'had', 'a', 'medic', 'reason', 'and', 'still', 'have', 'had', 'to', 'jump', 'thru', 'hoop', '.']
# Check Stemmed token data ['not', 'good', 'enough', '.', 'no', 'info', 'commun', 'at', 'ani', 'point', '-', 'just', 'silenc', '.', 'for', 'hour', 'as', 'we', 'sat', '.', 'oh', 'and', 'then', 'seat', 'wa', 'broken', '.']
# Check Stemmed token data ['suggest', '-', 'shade', 'on', 'the', 'window', 'so', 'travel', 'have', 'to', 'watch', 'ur', 'luggag', 'handler', 'throw', 'their', 'bag', 'around', 'wo', "n't"]
# Check Stemmed token data ['secondari', 'screen', 'a', 'piec', 'of', 'the', 'plane', 'miss', '...', 'anyth', 'you', 'want', 'to', 'tell', 'us', '?']
# Check Stemmed token data ['my', 'flight', 'is', 'cancel', 'flightl', '.', 'can', 'you', 'let', 'me', 'know', 'what', 'my', 'new', 'flight', 'info', 'is', '?']
# Check Stemmed token data ['inconveni', '?', 'are', 'you', 'peopl', 'freak', 'nut', '?', 'thi', 'guy', 'ha', 'two', 'kid', 'with', 'him', 'and', 'you', 'strand', 'him', 'in', 'an', 'airport', '!']
# Check Stemmed token data ['final', 'got', 'ahold', 'of', 'an', 'agent', 'after', 'anoth', 'hour', '.', 'thank', 'for', 'the', 'follow', 'up', '.', 'recommend', 'a', 'call', 'back', 'featur', '.']
# Check Stemmed token data ['be', 'told', 'by', 'thi', 'guy', 'that', 'he', 'will', 'not', 'help', 'us', 'sit', 'next', 'to', 'our', 'and', 'year', 'old', 'on', 'the', 'flight', '.']
# Check Stemmed token data ['an', 'over', 'book', 'flight', 'to', 'start', 'with', 'and', 'a', 'red', 'eye', 'from', 'lax', 'to', 'bo', 'with', 'no', 'reclin', 'seat', '...']
# Check Stemmed token data ['u', 'were', 'bae', 'until', 'u', 'lost', 'both', 'of', 'my', 'bag', 'and', 'had', 'no', 'clue', 'where', 'they', 'were', 'or', 'what', 'happen', 'to', 'them', 'for', 'hour', ':/']
# Check Stemmed token data ['polici', 'maker', 'need', 'to', 'chang', 'their', 'mindset', 'on', 'aviat', '.', 'fli', 'is', 'not', 'for', '...']
# Check Stemmed token data ['I', '❤', '️', 'jetblu', 'but', 'i', 'wa', 'on', 'flt', 'from', 'fll', 'to', 'sfo', '.', 'tke', 'off', 'wa', 'over', 'hr', 'late', 'flight', 'div', 'to', 'phx', 'got', 'in', 'hr', 'late', 'flight', '.', 'what', 'will', 'be', 'done', '?']
# Check Stemmed token data ['the', 'incompet', 'is', 'truli', 'stun', 'at', 'thi', 'point', '.', 'hour', 'on', 'a', 'plane', 'for', 'a', '1.75', 'hour', 'nonstop', 'flight', '.']
# Check Stemmed token data ['sjc-lax', '.', 'after', 'the', 'fourth', 'time', 'I', 'gave', 'up', '!']
# Check Stemmed token data ['ok', 'just', 'know', 'that', 'most', 'like', 'never', 'book', 'with', 'you', 'again', 'that', "'s", 'I', "'ll"]
# Check Stemmed token data ['-', 'realli', '?', 'U', 'land', 'me', 'in', 'philli', '1.5', 'hour', 'befor', 'my', 'flight', 'wait', '1.5', 'hour', 'behind', 'a', 'plane', 'you', 'got', 'stuck']
# Check Stemmed token data ['my', 'group', 'got', 'their', 'cancel', 'flightlat', 'fee', 'waiv', 'but', 'I', 'becaus', 'my', 'ticket', 'is', 'book', 'for', '2/18', '?', 'your', 'rep', 'were', 'no', 'help', 'either', '😡', 'ca', "n't"]
# Check Stemmed token data ['whi', 'would', 'I', 'even', 'consid', 'continu', 'your', 'point', 'program', 'when', 'I', 'receiv', 'no', 'perk', 'or', 'continu', 'bad', 'custom', 'servic', '?']
# Check Stemmed token data ['1/2', 'just', 'be', 'honest', 'with', 'your', 'custom', '.', 'the', 'new', 'seat', 'are', 'design', 'to', 'fit', 'more', 'row', 'on', 'the', 'plane', '.', 'more', 'row', '=', 'more', 'money', '.']
# Check Stemmed token data ['the', 'internet', 'is', 'a', 'great', 'thing', '.', 'I', 'am', 'email', 'execut', 'in', 'your', 'compani', 'mayb', 'they', 'will', 'respond', 'to', 'me', 'in', 'a', 'time', 'manner', '.']
# Check Stemmed token data ['after', 'min', 'they', 'tell', 'us', 'they', 'check', 'temperatur', 'for', 'at', 'least', 'more', 'hour', '.', 'so', 'back', 'to', 'the', 'gate', 'to', 'wait', '.', 'ca', "n't", 'it', "'s"]
# Check Stemmed token data ['are', 'you', 'kid', 'ME', '?', '?', 'bad', 'custom', 'servic', 'folk', '.', 'flew', 'from', 'psp', 'to', 'phx', 'flight', 'on', '2/19', '.', '(', 'cont', ')']
# Check Stemmed token data ['not', 'an', 'option', 'for', 'us', '.', 'so', 'how', 'can', 'we', 'help', 'each', 'other', 'fix', 'thi', '?', 'I', 'made', 'the', 'chang', 'earlier', 'if', 'given', 'accur', 'info', '.', 'that', "'s", 'would', "'ve"]
# Check Stemmed token data ['just', 'flew', 'to', 'paid', '$', '100', 'from', 'a', 'third', 'suitcas', 'which', 'even', 'make', 'it', 'on', 'the', 'plane', '!', 'besid', 'for', 'the', 'impolit', 'servic', '...', 'did', "n't"]
# Check Stemmed token data ['your', 'agent', 'forc', 'me', 'to', 'check', 'a', 'carri', 'on', 'bag', '.', 'when', 'I', 'receiv', 'my', 'bag', 'I', 'found', 'your', 'crew', 'had', 'stolen', 'from', 'me', '.', 'U', 'lost', 'my', 'busi', '!']
# Check Stemmed token data ['need', 'to', 'hold', 'or', 'get', 'a', 'call', 'back', '.', 'just', 'get', 'hung', 'up', 'on', 'by', 'your', 'phone', 'system', 'for', '6', '+', 'hour', 'now', '.']
# Check Stemmed token data ['can', 'you', 'make', 'sure', 'I', '’', 'm', 'on', 'the', 'upgrad', 'list', 'for', '2/23', 'ewr-pdx', 'use', 'my', 'gpu', 'prioriti', '?', 'got', 'a', 'weird', 'email', 'about', 'it', '.']
# Check Stemmed token data ['flight', 'cancel', 'flightl', '.', 'new', 'flight', 'hour', 'late', 'flightr', '.', 'will', 'sleep', 'in', 'airport', 'tonight', '.', 'and', 'cant', 'even', 'give', 'me', 'an', 'A', 'board', 'group', 'seat', '.', 'thx']
# Check Stemmed token data ['it', 'most', 'certainli', 'wa', 'not', '.']
# Check Stemmed token data ['are', 'you', 'guy', 'aliv', '?', 'been', 'on', 'hold', 'for', 'minut', 'and', 'count', '...', 'i', "'ve"]
# Check Stemmed token data ['want', 'to', 'explain', 'whi', 'I', 'wa', 'on', 'hold', 'for', '2', '+', 'hr', 'tonight', 'tri', 'to', 'reach', 'custom', 'servic', 'onli', 'to', 'learn', 'onli', 'there', 'mon-fr', '?', 'they', "'re"]
# Check Stemmed token data ['I', 'have', 'been', 'in', 'contact', 'with', 'peopl', 'and', 'still', 'no', 'answer', '.', 'you', 'keep', 'send', 'me', 'to', 'and', 'they', 'keep', 'send', 'me', 'to', 'you', '!']
# Check Stemmed token data ['a', 'friend', 'is', 'have', 'flight', 'cancel', 'flightlat', 'out', 'of', 'lax', 'to', 'cmh', 'on', 'feb', '23', '.', 'anyway', 'to', 'help', 'her', '?', 'number', 'ha', 'been', 'no', 'help']
# Check Stemmed token data ['so', 'am', 'I', 'suppos', 'to', 'discuss', 'thi', 'matter', 'with', 'a', 'comput', '?']
# Check Stemmed token data ['sorri', 'for', 'stray', 'and', 'go', 'with', 'learn', 'my', 'lesson', '.', 'these', 'attend', 'need', 'some', 'SW', 'happi', '!', 'I', "'m", 'I', "'ve"]
# Check Stemmed token data ['call', 'that', 'number', 'wa', 'useless', '.', 'head', 'to', 'the', 'airport', 'now', 'to', 'pick', 'up', 'my', 'bag', '.', 'thi', 'whole', 'situat', 'seem', 'like', 'a', 'real', 'joke', '.']
# Check Stemmed token data ['offer', 'to', 'pay', 'for', 'tix', 'at', 'the', 'airport', 'BC', 'we', 'were', 'never', 'told', 'that', 'our', 'reserv', 'go', 'through', '.', 'wa', 'told', 'I', 'could', 'pay', '$', '2275', 'pp', '.', 'did', "n't"]
# Check Stemmed token data ['...', 'just', 'call', 'and', 'ladi', 'at', 'your', 'oversea', 'call', 'center', 'said', 'she', 'saw', 'no', 'note', '.', 'I', 'explain', 'the', 'situat', '...', 'again', '...']
# Check Stemmed token data ['when', 'will', 'there', 'be', 'wifi', 'on', 'the', 'dca-stl', 'rout', '?', 'hour', 'flight', 'could', 'use', 'some', 'love', '!']
# Check Stemmed token data ['so', 'what', 'do', 'you', 'offer', 'now', 'that', 'my', 'flight', 'wa', 'cancel', 'flight', 'and', 'strand', 'away', 'from', 'home', 'and', 'work', '?', 'I', "'m"]
# Check Stemmed token data ['need', 'to', 'retrain', 'US', 'lead', 'flight', 'attend', 'and', 'gate', 'agent', 'at', 'arriv', 'mke', '2/23', '.', 'horribl', 'attitud', 'toward', 'help', 'custom', '.']
# Check Stemmed token data ['the', 'worst', 'first', 'class', 'board', 'servic', 'I', 'ever', 'had', '.']
# Check Stemmed token data ['13', '.', 'apolog', 'not', 'good', 'enough', '.', 'plane', 'with', 'mechan', 'and', 'hour', 'delay', 'unaccept', '.']
# Check Stemmed token data ['almost', 'half', 'hour', 'on', 'hold', '.', 'my', 'cell', 'phone', 'batteri', 'is', 'die', '.', 'thank', 'for', 'your', 'loyalti', 'from', 'a', '"', 'platinum', '"', 'member']
# Check Stemmed token data ['miss', 'connect', 'wrong', 'citi', 'bag', 'at', 'palm', 'spring', 'but', 'not', 'at', 'hotel', '.', 'I', 'am', 'serious', 'tire', 'of', 'be', 'treat', 'thi', 'way', '.']
# Check Stemmed token data ['.', 'we', 'rebook', '.', 'but', 'and', 'I', 'had', 'to', 'split', 'up', 'and', 'take', 'differ', 'flight', 'becaus', 'a', 'pilot', 'ran', 'out', 'of', 'hour', '?', 'frustrat', '.']
# Check Stemmed token data ['they', 'address', 'the', 'assult', 'or', 'drink', 'spill', 'on', 'her', 'the', 'drunk', 'passeng', 'had', 'to', 'have', 'a', 'wheelchair', 'to', 'get', 'off', 'plane', 'did', "n't"]
# Check Stemmed token data ['more', 'and', 'more', 'delay', '!', 'no', 'CS', 'help', 'at', 'all', '!', 'no', 'notif', '!']
# Check Stemmed token data ['your', 'chairman', 'phone', 'is', 'down', '.', 'what', 'other', 'number', 'can', 'i', 'use', '?']
# Check Stemmed token data ['hello', '...', 'my', 'baggag', 'ha', 'been', 'lost', 'in', 'anoth', 'citi', '.', 'can', 'anyon', 'help', 'me', 'with', 'thi', '?']
# Check Stemmed token data ['flight', 'had', 'sime', 'of', 'the', 'rudest', 'flight', 'attend', '.', 'I', 'wa', 'run', 'over', 'by', 'the', 'drink', 'card', 'and', 'had', 'a', 'flashlight', 'drop', 'on', 'me', '.']
# Check Stemmed token data ['whi', 'offer', 'autom', 'call', 'back', 'option', 'when', 'agent', 'is', 'avail', 'onli', 'to', 'call', 'me', 'have', 'me', 'sit', 'on', 'hold', '?', 'at', '12:30', 'am', '.']
# Check Stemmed token data ['your', 'servic', 'suck', '.']
# Check Stemmed token data ['ani', 'option', 'to', 'co', 'tonight', '?', 'look', 'like', '5525', 'will', 'make', 'it', 'in', 'time', 'for', '6259', '.', 'should', 'I', 'reserv', 'a', 'hotel', 'room', '?', 'doe', "n't"]
# Check Stemmed token data ['outsourc', 'ticket', 'and', 'gate', 'agent', 'at', 'mia', '.', 'ill', 'advis', '.', 'you', 'did', 'it', 'in', 'roc', 'and', 'servic', 'went', 'downhil', '.', 'keep', 'employe', 'and', 'flier', 'first']
# Check Stemmed token data ['yep', '.', '99.99999999', '%', 'certain', 'it', 'wa', 'on', 'that', 'flight', '.']
# Check Stemmed token data ['flight', 'just', 'cancel', 'flight', '.', 'can', 'you', 'help', 'me', 'rebook', '?']
# Check Stemmed token data ['that', 'is', 'a', 'stock', 'respons', '.', 'delay', 'not', 'as', 'frustrat', 'as', 'poor', 'cust', 'serv', 'be', 'told', 'by', 'ppl', 'to', 'wait', 'come', 'back', 'but', 'did', 'not', '.', 'they', "'d"]
# Check Stemmed token data ['you', 'can', 'pass', 'that', 'along', 'to', 'my', 'wife', 'daughter', 'friend', 'my', 'elderli', 'mother-in-law', '.', 'they', 'spent', 'sever', 'hour', 'wait', '.', 'daughter', "'s"]
# Check Stemmed token data ['ye', 'suppos', 'to', 'be', 'here', 'by', '6pm', '.', 'I', 'have', 'a', 'board', 'meet', 'tomorrow', '.', 'finger', 'cross', '.']
# Check Stemmed token data ['u', 'suck', 'big', 'donkey', 'ball', '!']
# Check Stemmed token data ['what', 'about', 'the', 'poor', 'custom', 'servic', 'at', 'checkin', 'at', 'kansa', 'kci', '?', '!', '?', 'it', '?', '?', '?', 'that', "'s"]
# Check Stemmed token data ['disappoint', 'that', 'my', 'flight', 'back', 'to', 'boston', 'from', 'PR', 'wa', 'cancel', 'flightledrebook', 'the', 'next', 'daydelay', 'that', 'one', 'too', 'and', 'no', 'compens']
# Check Stemmed token data ['how', 'do', 'I', 'chang', 'flight', '.', 'hour', 'is', 'crazi', 'pleas', 'help']
# Check Stemmed token data ['minut', 'to', 'board', 'at', 'b12', 'in', 'ord', '.', 'no', 'sign', 'of', 'gate', 'agent', '.', 'A', 'littl', 'help', '?']
# Check Stemmed token data ['I', 'book', 'our', 'flight', 'w', '/', '.', 'I', 'saw', 'the', 'same', 'price', 'each', 'time', 'I', 'search', '.', 'it', 'the', 'least', 'bit', 'frustrat', '.', 'wa', "n't"]
# Check Stemmed token data ['no', 'when', 'I', 'call', 'AA', 'now', 'I', 'even', 'get', 'on', 'hold', '...', 'can', 'you', 'help', 'me', '?', 'ca', "n't"]
# Check Stemmed token data ['how', 'long', 'for', 'a', 'repli']
# Check Stemmed token data ['u', 'give', 'an', 'answer', 'whi', 'the', 'flight', 'delay', 'so', 'long', '.', 'and', 'how', 'do', 'u', 'compens', 'miss', 'my', 'other', 'flight', 'lima', 'to', 'cuzco', '?', '?', 'did', "n't"]
# Check Stemmed token data ['what', 'do', 'you', 'call', 'that', '?', '?', '!', '!']
# Check Stemmed token data ['.', 'day', 'still', 'not', 'home', '.', 'not', 'even', 'off', 'the', 'ground', '.', '3', '.', 'day', '.']
# Check Stemmed token data ['flight', 'sit', 'fulli', 'load', 'for', 'over', 'an', 'hour', '.', 'air', 'condit', 'bare', 'work', ':-(']
# Check Stemmed token data ['...', 'and', 'when', 'that', 'work', '...', 'doe', "n't"]
# Check Stemmed token data ['I', 'am', 'now', 'follow', 'you', 'and', 'see', 'that', 'I', 'am', 'not', 'the', 'onli', 'one', 'experienc', 'and', 'notic', 'a', 'substanti', 'downgrad', 'in', 'servic', 'post', 'merger']
# Check Stemmed token data ['paid', 'to', 'upgrad', 'to', 'first', 'class', 'went', 'up', 'to', 'admir', 'club', 'at', 'phx', 'airport', 'to', 'be', 'turn', 'away', 'becaus', 'our', 'flight', 'is', 'to', 'cun', 'and', 'not', 'MC']
# Check Stemmed token data ['not', 'if', 'it', 'travel', 'credit', 'you', 'use', 'to', 'buy', 'and', 'it', 'expir', 'on', 'the', 'day', 'you', 'find', 'a', 'lower', 'rate']
# Check Stemmed token data ['yep', 'sent', 'my', 'bag', 'to', 'philadelphia', 'instead', 'of', 'miami', '...', 'I', 'caught', 'it', '...', 'then', 'wa', 'told', 'my', 'flight', 'chang', 'to', 'tomorrow', 'wrong', 'again']
# Check Stemmed token data ['my', 'flight', 'to', 'dalla', 'and', 'to', 'sfo', 'ha', 'been', 'cancel', 'flight', 'and', 'they', 'get', 'me', 'on', 'anyth', 'els', 'until', 'tomorrow', '.', 'you', 'put', 'ca', "n't", 'wo', "n't"]
# Check Stemmed token data ['taken', '~', '3', 'week', 'for', 'cust', 'care', 'to', 'respond', 'to', 'case', '#8477733', 'request', 'a', 'refund', 'for', 'wi-fi', 'not', 'work', '.', 'where', 'can', 'I', 'get', 'an', 'updat', '?', 'it', "'s"]
# Check Stemmed token data ['been', 'on', 'hold', 'for', 'over', 'an', 'hour', 'onli', 'b', '/', 'c', 'my', 'CC', 'mile', 'show', 'up', '.', 'what', 'a', 'mediocr', 'combo', 'of', 'cc', 'airlin', 'I', "'ve", 'are', "n't"]
# Check Stemmed token data ['3hr30min', 'right', 'now', '...', 'ani', 'end', 'in', 'sight', '?']
# Check Stemmed token data ['your', 'a-list', 'program', 'is', 'a', 'complet', 'joke', '!', 'your', 'compani', 'doe', 'not', 'valu', 'loyal', 'customers.tim', 'to', 'look', 'for', 'anoth', '"', 'go-to', '"', 'airlin']
# Check Stemmed token data ['I', 'have', 'been', 'on', 'hold', 'for', 'over', 'hour', '.', 'pleas', 'help', '!']
# Check Stemmed token data ['final', 'made', 'it', 'to', 'chicago', '-', 'hour', 'late', 'flight', '.', 'did', 'get', 'a', '$', '12', 'food', 'voucher', 'for', 'my', 'wait.about', '$', '1per', '/', 'hr', '.', 'never', 'again', '.', 'good', 'bye', '.']
# Check Stemmed token data ['congrat', 'just', 'lost', 'a', 'custom', 'for', 'good', '.', 'when', 'I', 'made', 'a', 'unit', 'weather', 'chang', 'free', '/', '5', 'min', '.', 'you', 'guy', 'hr', 'on', 'hold', '$', '25', '.', 'you', "'ve"]
# Check Stemmed token data ['understand', 'the', 'situat', 'we', 'wait', 'and', 'it', 'wa', 'open', 'until', '10:30', 'pm']
# Check Stemmed token data ['“', ':', 'so', 'sorri', 'for', 'your', 'frustrat', '.', 'did', 'you', 'get', 'rebook', '?', '^', 'SW', '”', 'been', 'rebook', 'time', '!', '!', 'still', 'stuck', '!', '!', 'I', "'m", 'I', "'ve"]
# Check Stemmed token data ['you', 'were', 'do', 'so', 'well', 'until', 'the', 'phl-sfo', 'flight', 'yesterday', '.', 'major', 'miss', '.', 'unfriendli', 'premier', 'cabin', 'crew', '.', 'baggag', 'cluster', 'at', 'sfo', '.']
# Check Stemmed token data ['abl', 'to', 'get', 'on', 'hold', '.', 'your', 'system', 'kept', 'kick', 'me', 'to', 'the', 'main', 'menu', '.', 'wa', "n't"]
# Check Stemmed token data ['want', 'me', 'to', 'get', 'home', 'doe', "n't"]
# Check Stemmed token data ['I', 'have', 'email', 'sever', 'times.hand', 'wrote', 'a', 'letterw', 'to', 'airportcalled.pleas', 'fix', 'thi', '!', 'or', '7newsbayarea', 'pleas', 'help', '!']
# Check Stemmed token data ['sure', 'know', 'how', 'to', 'pamper', 'custom', 'they', 'strand', 'abroad', '.', '4yourself']
# Check Stemmed token data ['they', 'are', 'now', 'be', 'sent', 'off', 'the', 'plane', '?', 'doe', 'anyon', 'at', 'jetblu', 'have', 'a', 'clue', '?']
# Check Stemmed token data ['and', 'our', 'meal', 'are', 'also', 'on', 'us', 'becaus', 'thi', 'compani', 'doe', 'not', 'care', 'about', 'their', '.', 'truli', 'disgrac', '.']
# Check Stemmed token data ['call', 'drop', 'no', 'call', 'back', '...', 'anoth', '45min', '-', 'hour', 'for', 'anoth', 'rep', '.', 'the', 'worst', 'CS', 'ever', 'onlin', 'by', 'phone', 'in', 'person', '.']
# Check Stemmed token data ['whi', 'did', 'you', 'book', 'my', 'hotel', 'twice', '?', '!', '?', '!', 'ahhhhh']
# Check Stemmed token data ['just', 'like', 'to', 'know', 'where', 'my', 'bag', 'is', 'when', 'get', 'it', 'and', 'whi', 'I', 'have', 'it', 'alreadi', '.', 'no', 'account', 'from', 'cust', 'servic', '.', 'I', "'d", 'I', "'ll", 'do', "n't"]
# Check Stemmed token data ['my', 'wife', 'is', 'tri', 'to', 'get', 'a', 'group', 'of', 'client', 'to', 'their', 'destin', 'and', 'just', 'got', 'disconnect', 'after', '2', 'hour', 'hold', '.', 'help', '.']
# Check Stemmed token data ['been', 'tri', 'to', 'call', 'your', 'reserv', 'desk', 'for', 'past', 'hour', 'and', 'get', 'through', '.', 'thi', 'is', 'not', 'what', 'I', 'expect', '.', 'I', "'ve", 'ca', "n't"]
# Check Stemmed token data ['where', 'is', 'the', '"', 'award', 'win', 'servic', '"', '?']
# Check Stemmed token data ['terribl', 'servic']
# Check Stemmed token data ['is', 'flight', 'on', '4/24', '/', '15', 'move', 'back', '?', 'when', 'I', 'book', 'it', 'said', 'we', 'arriv', '11:31', 'but', 'now', 'it', 'say', '12:08', '😢']
# ...
# Check Stemmed token data ['from', 'orlando', 'to', 'dca', '!', 'and', 'my', 'awesom', 'flight', 'attend', 'is', 'robert', '!']
# Check Stemmed token data ['amaz', 'servic', 'by', 'your', 'SW', 'stewardess', '!', 'from', 'den', 'to', 'cun', 'and', 'from', 'cun', 'to', 'atl', 'and', 'atl', 'to', 'lax', '.', 'thank', 'u', '!']
# Check Stemmed token data ['I', 'should', 'be', 'fine', '.', 'they', 'automat', 'chang', 'my', 'connect', 'flight', 'for', 'me', 'so', 'I', 'miss', 'it', '.', 'A', '+', 'work', '.', 'would', "n't"]
# Check Stemmed token data ['thank', '!']
# Check Stemmed token data ['thank', 'so', 'much', 'for', 'your', 'condol', 'and', 'quick', 'respons', '.', 'it', 'is', 'veri', 'much', 'appreci']
# Check Stemmed token data ['great', 'will', 'do', 'onc', 'I', 'land', 'in', 'jfk']
# Check Stemmed token data ['thank', 'you', '!']
# Check Stemmed token data ['had', 'a', 'great', 'LA', 'flight', 'with', 'clarenc', 'and', 'frank', '!', 'those', 'guy', 'are', 'a', 'hoot', '!', '😜', '😂', 'thank']
# Check Stemmed token data ['thank', 'alreadi', 'subscrib', 'and', 'have', 'a', 'RR', 'account', '.', 'had', 'receiv', 'a', 'promo', 'code', 'last', 'month', 'but', 'ha', 'sinc', 'expir', '.', 'ani', 'new', 'offer', '?']
# Check Stemmed token data ['happi', 'to', 'spend', 'the', 'day', 'togeth', '.', 'do', 'thi', '!', 'let', "'s"]
# Check Stemmed token data ['wonder', 'FC', 'FA', 'on', 'flight', 'pre', 'dawn', '!', 'nice', 'start', 'to', 'the', 'day', '!']
# Check Stemmed token data ['stop', '.', 'pleas', '.', 'RT', ':', 'our', 'on', 'fleek', '.', 'fleet', "'s"]
# Check Stemmed token data ['they', 'are', 'all', '-', 'pilot', 'FA', 'and', 'ground', 'personnel', 'do', 'a', 'great', 'job', '.', 'weather', 'is', 'to', 'blame', '...', 'who', 'do', 'I', 'talk', 'to', 'about', 'that', ':)']
# Check Stemmed token data ['got', 'it', 'thank', '!']
# Check Stemmed token data ['thank', 'to', 'the', 'gent', 'on', 'the', 'phone', 'who', 'fix', 'my', 'bos-mco', 'flight', 'and', 'the', 'fee', 'waiver', '!', 'a320', 'now', ':)', '!', 'I', 'forget', 'her', 'name', ':(']
# Check Stemmed token data ['my', 'favorit', 'way', 'to', 'travel', '!', 'thank', 'you', '!']
# Check Stemmed token data ['thank', 'you', '!', '!', '!', 'thi', 'whole', 'crew', 'ha', 'rock', 'through', 'bad', 'weather', 'and', 'divers', '.', 'pilot', 'keep', 'us', 'well', 'inform', '.']
# Check Stemmed token data ['"', 'airport', 'snow', 'remov', 'method', '#22', '..', '"', 'keep', 'up', 'the', 'good', 'work', 'folk', 'thi', 'is', 'where', 'becom', '747', "'", 's', '!', 'cessna', "'s"]
# Check Stemmed token data ['thank', 'you', '!', '!', '!']
# Check Stemmed token data ['ahah', '😃', '💕', '🎵', 'that', 'is', 'whi', 'I', 'love', 'SW', '✈', '❗', '(', '^', '^', ')', '❤']
# Check Stemmed token data ['head', 'to', 'buffalo', '...', 'trade', 'the', 'cold', 'in', 'boston', 'for', 'colder', 'in', 'buffalo', '...', 'mayb', 'the', 'caribbean', 'next', 'time', '?']
# Check Stemmed token data ['wow', '.', 'what', 'a', 'deal', '.', 'again', '30', '+', 'plu', 'seat', 'avail', '.', 'easi', 'chang', 'to', 'make', 'a', 'custom', 'happi', '.']
# Check Stemmed token data ['you', 'togeth', 'are', 'the', 'best', 'part', 'of', 'fli', '!']
# Check Stemmed token data ['thank', 'you', 'so', 'much', 'for', 'your', 'effort']
# Check Stemmed token data ['love', 'love', 'love', 'thi', '.', 'southwest', 'rock', '!', '!', 'alway', '!', '!']
# Check Stemmed token data ['see', 'your', 'worker', 'time', 'in', 'and', 'time', 'out', 'go', 'abov', 'and', 'beyond', 'is', 'whi', 'I', 'love', 'fli', 'with', 'you', 'guy', '.', 'thank', 'you', '!']
# Check Stemmed token data ['ok', 'have', 'sent', 'u', 'info', 'via', 'DM', '.', 'I', 'appreci', 'your', 'help', 'and', 'consider', '.', '😊']
# Check Stemmed token data ['gate', 'attend', 'at', 'mccarran', 'c16', '(', 'vega', 'to', 'dalla', ')', 'went', 'abov', 'and', 'beyond', '.', 'after', 'a', 'long', 'day', 'of', 'frustrat', 'it', 'wa', 'welcom', '.']
# Check Stemmed token data ['well', 'the', 'last', 'updat', 'wa', 'in', 'the', 'right', 'direct', 'at', 'least', '!', 'keep', 'my', 'finger', 'cross', '.', 'I', "'ll"]
# Check Stemmed token data ['!', 'and', 'done', 'and', 'head', 'to', 'warmer', 'weather', '!', 'we', "'re"]
# Check Stemmed token data ['thank', '.', 'if', 'you', 'have', 'anoth', 'method', 'also', 'that', 'would', 'be', 'nice', '.', 'appear', 'to', 'be', 'a', 'design', 'flaw']
# Check Stemmed token data ['_green', 'just', 'receiv', 'it', 'actual', '.', 'thank', 'you', '!', '!', '!']
# Check Stemmed token data ['you', 'know', 'be', 'beyond', 'awesom', '?', 'A', 'pair', 'of', 'ticket', 'to', 'the', 'show', 'in', 'atl', '.', 'A', 'girl', 'can', 'dream', 'what', "'d"]
# Check Stemmed token data ['fav', 'airlin']
# Check Stemmed token data ['thank', 'you', 'so', 'much', 'it', 'been', 'a', 'veri', 'stress', 'day']
# Check Stemmed token data ['good', '.', 'thank', 'you', '!', 'you', "'re"]
# Check Stemmed token data ['thank', 'so', 'much', 'just', 'had', 'to', 'make', 'a', 'cancel', 'flightlat', '!', 'sent', 'u', 'the', 'info', '.', 'I', "'ve"]
# Check Stemmed token data ['got', 'it', 'squar', 'away', '.', 'thank', 'you', '.', 'I', 'had', 'a', 'man', 'on', 'the', 'insid', 'help', 'me', 'out', '!']
# Check Stemmed token data ['-', 'I', 'just', 'had', 'a', 'great', 'experi', 'with', 'your', 'custom', 'servic', 'team', '.', 'thank', 'you', '!', 'a-list']
# Check Stemmed token data ['look', 'like', 'they', 'came', 'through', '.', 'thank', 'again', 'for', 'the', 'help', '.']
# Check Stemmed token data ['...', 'have', 'you', 'seen', 'blue', '?', 'go', 'look', 'it', 'up', ':)']
# Check Stemmed token data ['my', 'bag', 'refer', 'ID', 'number', 'is', 'ind', '43728m', '.', 'thank', 'for', 'look', 'at', 'it', '.']
# Check Stemmed token data ['“', ':', 'look', 'for', 'a', 'reason', 'to', 'travel', '?', '”']
# Check Stemmed token data ['chair', '"', ':', '6', 'everyon', 'look', ';)', 'so', 'proud', 'of', 'our', 'phl', 'crew', '!', '”', 'we', "'re"]
# Check Stemmed token data ['can', 'you', 'bring', 'guinea', 'pig', 'in', 'small', 'pet', 'carrier', 'onboard', 'your', 'flight', '?']
# Check Stemmed token data ['"', 'airport', 'snow', 'remov', 'method', '#22', '...', '"', 'keep', 'up', 'the', 'good', 'work', 'folk', 'thi', 'is', 'where', 'becom', '747', "'", 's', '!', 'cessna', "'s"]
# Check Stemmed token data ['crew', 'of', 'wn3946', 'san-sfo', 'wa', 'brilliant', '!', 'rita', 'wa', 'hilari', '.', 'I', 'know', 'been', 'down', 'on', 'you', 'befor', 'but', 'thi', 'wa', 'a', 'great', 'flight', 'I', "'ve"]
# Check Stemmed token data ['thank', 'for', 'forc', 'me', 'to', 'check', '-', 'in', 'my', 'carri', '-', 'on', 'luggag', '.', 'that', 'is', 'exactli', 'whi', 'I', 'spent', 'extra', 'money', 'on', '"', 'travel', 'size', '"', 'toiletri']
# Check Stemmed token data ['wow', 'keep', 'up', 'with', 'the', 'time', '...']
# Check Stemmed token data ['thank', '!']
# Check Stemmed token data ['thank', 'you', 'for', 'the', 'speedi', 'respons', '!', 'I', 'figur', 'it', 'may', 'be', 'someth', 'of', 'that', 'natur', '.', 'you', 'guy', 'and', 'your', '"', 'fine', 'print', '"', 'haha']
# Check Stemmed token data ['love', 'the', 'new', 'plane', 'for', 'the', 'jfk-lax', 'run', '.', 'mayb', 'one', 'day', 'I', 'will', 'be', 'on', 'one', 'where', 'the', 'amen', 'all', 'function', '.']
# Check Stemmed token data ['ye', 'pleas', '.']
# Check Stemmed token data ['that', 'made', 'me', 'so', 'mad', 'but', 'then', 'I', 'call', 'the', 'bag', 'number', 'and', 'that', 'person', 'wa', 'help', 'and', 'told', 'me', 'where', 'the', 'bag', 'realli', 'wa', '.', '(', '2/2', ')']
# Check Stemmed token data ['thank', 'you', 'for', 'take', 'care', 'of', 'me', 'with', 'a', 'drink', 'sinc', 'my', 'in-flight', 'entertain', 'work', 'wa', "n't"]
# Check Stemmed token data ['you', 'have', 'a', 'guy', 'name', 'oti', 'at', 'ord', 'that', 'know', 'what', 'is', '.', 'he', 'wa', 'abl', 'to', 'get', 'my', 'bag', 'to', 'me', '.', 'I', 'upgrad', 'just', 'to', 'be', 'sure']
# Check Stemmed token data ['thank', 'gang', '!', 'mind', 'if', 'I', 'ask', 'do', 'you', 'handl', 'all', 'of', 'your', 'social', 'media', 'in', 'hous', '?']
# Check Stemmed token data ['shoutout', 'to', 'the', 'agent', 'on', 'duti', 'now', '@', 'gate', 'B1', '/', 'outstand', 'custom', 'servic', 'w', 'delay', 'flt']
# Check Stemmed token data ['anoth', 'great', 'trip', '!', 'lax', '-', 'la', '3075', '-', 'bna', '.', 'thank', 'so', 'much', '!', '!', '!']
# Check Stemmed token data ['thank', 'you', '.', 'there', 'wa', 'one', 'here', 'a', 'few', 'month', 'ago', 'but', 'none', 'now', '.', 'weird', 'you', 'have', 'a', 'club', 'in', 'one', 'of', 'the', 'busiest', 'airport', 'in', 'the', 'US', '.', 'do', "n't"]
# Check Stemmed token data ['great', 'thank', 'you']
# Check Stemmed token data ['that', 'guy', 'wa', 'the', 'flight', 'attend', 'on', 'my', 'last', 'flight', '…', 'he', 'wa', 'hilari', '!', '☺']
# Check Stemmed token data ['oh', 'that', 'total', 'look', 'on', 'par', 'with', "'", 's', 'admir', 'club', ';', 'ani', 'way', 'you', 'can', 'slide', 'us', 'a', 'coupl', 'pass', '?', ';)']
# Check Stemmed token data ['thank', 'for', 'the', 'repli', 'but', 'a', 'function', 'plane', 'four', 'hour', 'ago', 'wa', 'the', 'onli', 'way', 'to', 'do', 'that', '.', 'the', 'staff', 'wa', 'friendli', 'tho', '.']
# Check Stemmed token data ['sent', 'a', 'DM', 'just', 'now', '.', 'thank', 'I', 'am', 'incred', 'happi', 'the', 'fast', 'respons', 'I', 'got', 'via', 'twitter', 'than', 'via', 'custom', 'care', '.', 'thank', 'you']
# Check Stemmed token data ['my', 'home', 'for', 'the', 'next', '8.5', 'hr', '.', 'gfc', '!', ':)']
# Check Stemmed token data ['giant', 'and', 'virgin', 'america', '.', 'A', 'match', 'made', 'in', 'heaven', '.']
# Check Stemmed token data ['aww', 'cool', '!', 'nice', 'to', 'know', 'they', 'are', 'still', 'up', 'abov', 'my', 'head', 'then', '.', 'one', 'of', 'my', 'fave', '.', 'it', "'s"]
# Check Stemmed token data ['hmm', '.', 'look', 'like', 'you', 'look', 'at', 'my', 'tweet', 'from', 'last', 'month', 'not', 'thi', 'one', '.', 'wa', 'abl', 'to', 'get', 'U', '.', 'K', '.', 'agent', 'to', 'help', 'me', 'thank', '.']
# Check Stemmed token data ['thank']
# Check Stemmed token data ['seem', 'a', 'few', 'of', 'my', 'friend', 'speak', 'highli', 'as', 'well', '.', 'now', 'we', 'just', 'need', 'to', 'find', 'a', 'decent', 'price', 'way', 'to', 'go', 'from', 'yvr', 'to', 'sea', 'and', 'overnight', '.']
# Check Stemmed token data ['mint', 'seat', 'are', 'awesom', '!', ':-)', 'best', 'busi', 'class', 'in', 'the', 'US', '!', '!', '!']
# Check Stemmed token data ['fine', '.', 'take', 'them', '.', 'that', "'s", 'I', "'ll"]
# Check Stemmed token data ['done', '!', 'also', 'look', 'like', 'you', 'open', 'some', 'up', 'on', 'my', 'flight', 'to', 'vega', 'on', 'sunday', '!', '💙']
# Check Stemmed token data ['on', 'my', 'flight', 'today', 'from', 'rsw', 'to', 'grr', 'I', 'wa', 'abl', 'to', 'snag', 'a', 'free', 'SW', 'agent', 'to', 'check', 'for', 'me', '.', 'it', 'look', 'like', 'we', 'are', '(', 'final', ')', 'all', 'set', '.']
# Check Stemmed token data ['thank', 'you', 'truli', 'appreci', 'the', 'help', 'just', 'sent', 'a', 'DM']
# Check Stemmed token data ['thank', '!']
# Check Stemmed token data ['flt', '912', '.', 'capt', 'herman', 'is', 'amaz', '!', 'came', 'out', 'befor', 'flight', 'to', 'play', '"', 'ask', 'the', 'captain', 'anyth', '.', '"', 'wonder', 'ambassador', 'to', 'the', 'airlin', '!', '!']
# Check Stemmed token data ['you', 'definit', 'will', '!']
# Check Stemmed token data ['thank']
# Check Stemmed token data ['I', 'did', 'not', '!', 'a', 'woman', 'a', 'lead', 'she', 'wa', 'work', 'at', 'gate', 'c26', '.', 'she', "'s", 'who', "'s"]
# Check Stemmed token data ['credit', 'to', 'you', 'for', 'repli', '.', 'I', '’', 'll', 'look', 'forward', 'to', 'hope', 'one', 'of', 'those', 'on', 'my', 'flight', 'home', 'tonight', ':)']
# Check Stemmed token data ['I', 'made', 'it', '-', 'thx', '.']
# Check Stemmed token data ['wa', 'far', 'less', 'pain', 'than', 'what', 'wa', 'come', 'from', 'avi', '.', '💙']
# Check Stemmed token data ['eyyyi', '!', 'cancel', 'flightlat', 'flight', 'book', 'problemss', 'reflight', 'book', 'problemss', 'but', 'got', 'me', 'on', 'the', 'same', 'flight', 'out', 'tonight', '(', 'not', 'tomorrow', ')', 'the', 'FC', 'upgrad', '.', 'thx', '!', "y'all"]
# Check Stemmed token data ['thank', 'you', '!']
# Check Stemmed token data ['but', 'your', 'flight', 'crew', 'ground', 'crew', 'have', 'handl', 'situat', 'well', '.', 'text', 'notif', 'let', 'me', 'catch', 'a', 'few', 'wink', 'dure', 'delay', '.']
# Check Stemmed token data ['sivi', 'stewart', 'at', 'lax', 'wa', 'fantast', 'tonight', 'help', 'to', 'find', 'a', 'lost', 'item', 'for', 'us', 'at', 'the', 'airport', '.', 'much', 'thank', '!']
# Check Stemmed token data ['that', 'would', 'be', 'great', '-', '1k', 'us651621']
# Check Stemmed token data ['ye', 'ye', 'yesso', 'glad', 'to', 'be', 'head', 'home', '!']
# Check Stemmed token data ['cxl', 'flight', '.', 'rebook', 'pax', 'no', 'problem', '.', 'thank', 'you', 'and', 'everyon', 'at', 'AA', 'for', 'help', 'us', 'all', 'out', '!']
# Check Stemmed token data ['ok', 'thank', 'you', '!', 'have', 'a', 'great', 'night', 'AA', 'team', '!']
# Check Stemmed token data ['thank', 'for', 'the', 'person', 'custom', 'servic', '!']
# Check Stemmed token data ['thank', 'for', 'make', 'my', 'trip', 'home', 'next', 'flight', 'take', 'more', 'selfi', '!', 'I', "'ll"]
# Check Stemmed token data ['thank', 'for', 'the', 'time', 'servic', 'great', 'staff', 'get', 'my', 'wife', 'and', 'me', 'to', 'and', 'from', 'cancun', 'thi', 'past', 'week', 'for', 'our', 'honeymoon', '.']
# Check Stemmed token data ['cool', 'thx', '!', 'onli', 'a', 'coupl', 'more', 'flight', 'til', '...', 'wait', '.', 'will', 'be', 'easier', 'to', 'chang', 'flight', 'when', 'weather', 'bad', 'I', "'m", 'ca', "n't"]
# Check Stemmed token data ['although', 'the', 'wait', 'wa', 'long', 'due', 'to', 'weather', 'r', '/', 'schedul', 'a', 'phone', 'call', 'and', 'super', 'rep', 'solv', 'the', 'issu', '!', 'thank', 'you', '!', '!']
# Check Stemmed token data ['thank', 'you', '!', '!', '!']
# Check Stemmed token data ['congrat', '!']
# Check Stemmed token data ['thank', 'you', 'for', 'a', 'great', 'flight', 'in', 'gfc', ':)', 'cheer']
# Check Stemmed token data ['we', 'had', 'earli', 'bird', 'and', 'it', 'wa', 'great', '.', 'your', 'employe', 'were', 'awesom', '.', 'it', 'wa', 'passeng', 'who', 'kill', 'the', 'buzz', '.']
# Check Stemmed token data ['excel', '.', 'you', 'guy', 'are', 'the', 'best']
# Check Stemmed token data ['frustrat', 'day', '!', 'no', 'flight', 'home', 'chang', 'airlin', '.', 'thank', 'you', 'phl', 'usairway', 'employe', 'for', 'help', 'get', 'me', 'back', 'to', 'iah', '.']
# Check Stemmed token data ['oh', 'no', 'worri', 'NL', 'no', 'disappoint', 'here', '.', 'better', 'to', 'have', 'NO', 'loung', 'than', 'like', 'who', 'ha', 'them', 'but', 'doe', 'disappoint', '!']
# Check Stemmed token data ['I', 'love', '!', 'when', 'will', 'we', 'be', 'abl', 'to', 'charg', 'our', 'devic', 'on', 'domest', '320', 'flight', '?', '!', 'thank', '!']
# Check Stemmed token data ['I', 'would', 'love', 'to', 'go', 'to', 'the', 'atlanta', 'show', '♥', '️']
# Check Stemmed token data ['😃', 'cool']
# Check Stemmed token data ['thank', 'to', 'I', 'get', 'to', 'go', 'to', 'the', 'show', 'thi', 'weekend', 'in', 'utah', '!', '!', '!']
# Check Stemmed token data ['is', 'the', 'greatest', 'airlin', 'ever', '💕', '✈', '️', '💺']
# Check Stemmed token data ['your', 'agent', '(', 'and', 'servic', ')', 'on', 'my', 'weekend', 'trip', 'have', 'been', 'amaz', '!', '!', '!', 'thank', 'you', '!', '!']
# Check Stemmed token data ['ok', 'thx', '!']
# Check Stemmed token data ['thank', 'for', 'great', 'servic', 'in', 'newark', '.', 'seat', 'fix', 'and', 'I', 'wa', 'seat', 'with', 'my', 'daughter', '!', 'fab', 'land', 'in', 'fort', 'myer', '!']
# Check Stemmed token data ['thank', 'for', 'a', 'speedi', 'flight', 'time', 'recoveri', '.']
# Check Stemmed token data ['I', 'am', 'blown', 'away', 'by', 'stellar', '!', '!', 'thank', 'you']

# %%
print('Load TrainSet:%d/%d positive/negative samples.' 
      %(sum(labelTrain), len(labelTrain)-sum(labelTrain)))
np.savez('tmp/Train.npz', 
         labelTrain = labelTrain, 
         dataTrain =dataTrain, 
         dataTrainStem = dataTrainStem)

# Load TrainSet: 1181/3000 positive/negative samples.
# Out:
# Load TrainSet:0/0 positive/negative samples.

# %%
 print(labelTrain)
# Out:
# []

# %%
dset = np.load('./tmp/Train.npz', allow_pickle = True)
labelTrain = dset['labelTrain']
print(dset)
# Out:
# <numpy.lib.npyio.NpzFile object at 0x000001E8A2369DD8>

# %% [markdown]
# ### Linear Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
my_model = LogisticRegression()

# %%
# Scikit-Learn
def TrainLogisticRegression(features):
    
    def sigmoid(z):
        return np.exp(z)/(np.exp(z)+1)
    #sigmoid(0.5)   
    dset = np.load('./tmp/Train.npz', allow_pickle = True)
    labelTrain = dset['labelTrain']
    
    my_model = LogisticRegression()
    
    # Define Dataset
    X = np.load('labelTrain.npy')
    Y = np.load('lavelTest.npy')
    
    # fit X, Y
    my_model.fit(X,Y)
    
    # predict 
    print("Accuracy = ", my_model.score(X,Y))
